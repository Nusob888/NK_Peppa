# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager
import seaborn as sns
import anndata
import scanpy as sc
import re
import decoupler as dc
import sc_toolbox
import random
import seaborn.objects as so

# %%
data_dir = "/well/immune-rep/users/vbw431/Projects/Peppa/data/"
newdata_dir = "/well/immune-rep/users/vbw431/Projects/Peppa/new_analysis/data/"
plot_dir = "/well/immune-rep/users/vbw431/Projects/Peppa/new_out/final_plots/"

sys.path = sys.path + ["/well/immune-rep/users/vbw431/python_utils/"]

# %%
import rpy2.rinterface_lib.callbacks
import anndata2ri
import logging
import rpy2.robjects.lib.ggplot2 as gp
from rpy2.robjects import pandas2ri
from rpy2.robjects import r
from rpy2.ipython.ggplot import image_png

#sc.settings.verbosity = 0
rpy2.rinterface_lib.callbacks.logger.setLevel(logging.ERROR)

pandas2ri.activate()
anndata2ri.activate()
# %load_ext rpy2.ipython
# Out:
# /well/immune-rep/users/vbw431/conda/ivybridge/envs/scverse_new/lib/python3.8/site-packages/rpy2/robjects/lib/ggplot2.py:70: UserWarning: This was designed againt ggplot2 versions starting with 3.3. but you have 3.4.2
#   warnings.warn(

# %%
# %%R
# .libPaths(c(paste0("/well/immune-rep/users/vbw431/conda/ivybridge/envs/scverse_new/r_modules"), .libPaths()))
#
# library(tidyverse)
# library(Seurat)
# library(SCPA)
#
# cur.dir = "/well/immune-rep/users/vbw431/Projects/Peppa/data/DIMITRA_FASTQ/"
# work.dir = "/well/immune-rep/users/vbw431/Projects/Peppa/"
# out.dir = "/well/immune-rep/users/vbw431/Projects/Peppa/new_analysis/out/"
# references = "/well/immune-rep/users/vbw431/reference/reference/refdata-gex-GRCh38-2020-A/"
# com.out = "/well/immune-rep/users/vbw431/Projects/Peppa/reference_combat/"
#
# ##plotting
# library(ggplot2); theme_set(theme_bw(base_size = 18)+
#                               theme(strip.text = element_text(colour = 'black', face="bold",size=12),
#                                     panel.grid.major = element_blank(),
#                                     panel.grid.minor = element_blank(),
#                                     panel.border = element_rect(size = 0.7),
#                                     axis.ticks.length=unit(.10, "cm"),
#                                     axis.ticks = element_line(size=0.7),
#                                     strip.background = element_blank()))

# %%
# %%R
#
# ##load, normalise  and trim to remove pre_treatment replicates and post vaccine samples from azimuth
#
# peppa <- readRDS(paste0(out.dir, "/peppa_pbmc_all.rds"))
# peppa <- subset(peppa, subset = celltype_consensus.l1 == "NK")
# ##filter pre vaccination samples and pre treatment samples out
# peppa <- subset(peppa, subset = Treatment_status != "Pre_treatment")
#
# trim_barcodes <- peppa@meta.data %>%
#   dplyr::select(orig.ident) %>%
#   dplyr::filter(grepl("_0|SeuratProject", orig.ident))
# table(trim_barcodes)
#
# peppa <- subset(peppa, cells = rownames(trim_barcodes))

# %%
# %%R
# ##Normalise data
# peppa <- peppa %>%
#   NormalizeData() %>%
#   ScaleData()

# %%
# %%R
# library(msigdbr)
# library(magrittr)
#
# pathways <- c("hallmark", "kegg", "reactome")
# hkr_sets <- msigdbr("Homo sapiens") %>%
#   filter(grepl(paste(pathways, collapse = "|"), gs_name, ignore.case = T)) %>%
#   format_pathways()

# %%
# %%R
# hkr_sets
# Out:
# <list_of<
#   tbl_df<
#     Pathway: character
#     Genes  : character
#   >
# >[1851]>
# [[1]]
# # A tibble: 210 x 2
#    Pathway               Genes
#    <chr>                 <chr>
#  1 HALLMARK_ADIPOGENESIS ABCA1
#  2 HALLMARK_ADIPOGENESIS ABCB8
#  3 HALLMARK_ADIPOGENESIS ACAA2
#  4 HALLMARK_ADIPOGENESIS ACADL
#  5 HALLMARK_ADIPOGENESIS ACADM
#  6 HALLMARK_ADIPOGENESIS ACADS
#  7 HALLMARK_ADIPOGENESIS ACLY
#  8 HALLMARK_ADIPOGENESIS ACO2
#  9 HALLMARK_ADIPOGENESIS ACOX1
# 10 HALLMARK_ADIPOGENESIS ADCY6
# # i 200 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[2]]
# # A tibble: 335 x 2
#    Pathway                      Genes
#    <chr>                        <chr>
#  1 HALLMARK_ALLOGRAFT_REJECTION AARS1
#  2 HALLMARK_ALLOGRAFT_REJECTION ABCE1
#  3 HALLMARK_ALLOGRAFT_REJECTION ABI1
#  4 HALLMARK_ALLOGRAFT_REJECTION ACHE
#  5 HALLMARK_ALLOGRAFT_REJECTION ACVR2A
#  6 HALLMARK_ALLOGRAFT_REJECTION AKT1
#  7 HALLMARK_ALLOGRAFT_REJECTION APBB1
#  8 HALLMARK_ALLOGRAFT_REJECTION B2M
#  9 HALLMARK_ALLOGRAFT_REJECTION B2M
# 10 HALLMARK_ALLOGRAFT_REJECTION BCAT1
# # i 325 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[3]]
# # A tibble: 102 x 2
#    Pathway                    Genes
#    <chr>                      <chr>
#  1 HALLMARK_ANDROGEN_RESPONSE ABCC4
#  2 HALLMARK_ANDROGEN_RESPONSE ABHD2
#  3 HALLMARK_ANDROGEN_RESPONSE ACSL3
#  4 HALLMARK_ANDROGEN_RESPONSE ACTN1
#  5 HALLMARK_ANDROGEN_RESPONSE ADAMTS1
#  6 HALLMARK_ANDROGEN_RESPONSE ADRM1
#  7 HALLMARK_ANDROGEN_RESPONSE AKAP12
#  8 HALLMARK_ANDROGEN_RESPONSE AKT1
#  9 HALLMARK_ANDROGEN_RESPONSE ALDH1A3
# 10 HALLMARK_ANDROGEN_RESPONSE ANKH
# # i 92 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[4]]
# # A tibble: 36 x 2
#    Pathway               Genes
#    <chr>                 <chr>
#  1 HALLMARK_ANGIOGENESIS APOH
#  2 HALLMARK_ANGIOGENESIS APP
#  3 HALLMARK_ANGIOGENESIS CCND2
#  4 HALLMARK_ANGIOGENESIS COL3A1
#  5 HALLMARK_ANGIOGENESIS COL5A2
#  6 HALLMARK_ANGIOGENESIS CXCL6
#  7 HALLMARK_ANGIOGENESIS FGFR1
#  8 HALLMARK_ANGIOGENESIS FSTL1
#  9 HALLMARK_ANGIOGENESIS ITGAV
# 10 HALLMARK_ANGIOGENESIS JAG1
# # i 26 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[5]]
# # A tibble: 231 x 2
#    Pathway                  Genes
#    <chr>                    <chr>
#  1 HALLMARK_APICAL_JUNCTION ACTA1
#  2 HALLMARK_APICAL_JUNCTION ACTB
#  3 HALLMARK_APICAL_JUNCTION ACTC1
#  4 HALLMARK_APICAL_JUNCTION ACTG1
#  5 HALLMARK_APICAL_JUNCTION ACTG2
#  6 HALLMARK_APICAL_JUNCTION ACTN1
#  7 HALLMARK_APICAL_JUNCTION ACTN2
#  8 HALLMARK_APICAL_JUNCTION ACTN3
#  9 HALLMARK_APICAL_JUNCTION ACTN4
# 10 HALLMARK_APICAL_JUNCTION ACTN4
# # i 221 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[6]]
# # A tibble: 46 x 2
#    Pathway                 Genes
#    <chr>                   <chr>
#  1 HALLMARK_APICAL_SURFACE ADAM10
#  2 HALLMARK_APICAL_SURFACE ADIPOR2
#  3 HALLMARK_APICAL_SURFACE ADIPOR2
#  4 HALLMARK_APICAL_SURFACE AFAP1L2
#  5 HALLMARK_APICAL_SURFACE AKAP7
#  6 HALLMARK_APICAL_SURFACE APP
#  7 HALLMARK_APICAL_SURFACE ATP6V0A4
#  8 HALLMARK_APICAL_SURFACE ATP8B1
#  9 HALLMARK_APICAL_SURFACE B4GALT1
# 10 HALLMARK_APICAL_SURFACE BRCA1
# # i 36 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[7]]
# # A tibble: 183 x 2
#    Pathway            Genes
#    <chr>              <chr>
#  1 HALLMARK_APOPTOSIS ADD1
#  2 HALLMARK_APOPTOSIS AIFM3
#  3 HALLMARK_APOPTOSIS ANKH
#  4 HALLMARK_APOPTOSIS ANXA1
#  5 HALLMARK_APOPTOSIS APP
#  6 HALLMARK_APOPTOSIS ATF3
#  7 HALLMARK_APOPTOSIS AVPR1A
#  8 HALLMARK_APOPTOSIS BAX
#  9 HALLMARK_APOPTOSIS BCAP31
# 10 HALLMARK_APOPTOSIS BCL10
# # i 173 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[8]]
# # A tibble: 114 x 2
#    Pathway                       Genes
#    <chr>                         <chr>
#  1 HALLMARK_BILE_ACID_METABOLISM ABCA1
#  2 HALLMARK_BILE_ACID_METABOLISM ABCA2
#  3 HALLMARK_BILE_ACID_METABOLISM ABCA3
#  4 HALLMARK_BILE_ACID_METABOLISM ABCA4
#  5 HALLMARK_BILE_ACID_METABOLISM ABCA5
#  6 HALLMARK_BILE_ACID_METABOLISM ABCA6
#  7 HALLMARK_BILE_ACID_METABOLISM ABCA8
#  8 HALLMARK_BILE_ACID_METABOLISM ABCA9
#  9 HALLMARK_BILE_ACID_METABOLISM ABCD1
# 10 HALLMARK_BILE_ACID_METABOLISM ABCD2
# # i 104 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[9]]
# # A tibble: 77 x 2
#    Pathway                          Genes
#    <chr>                            <chr>
#  1 HALLMARK_CHOLESTEROL_HOMEOSTASIS ABCA2
#  2 HALLMARK_CHOLESTEROL_HOMEOSTASIS ACAT2
#  3 HALLMARK_CHOLESTEROL_HOMEOSTASIS ACSS2
#  4 HALLMARK_CHOLESTEROL_HOMEOSTASIS ACTG1
#  5 HALLMARK_CHOLESTEROL_HOMEOSTASIS ADH4
#  6 HALLMARK_CHOLESTEROL_HOMEOSTASIS ALCAM
#  7 HALLMARK_CHOLESTEROL_HOMEOSTASIS ALDOC
#  8 HALLMARK_CHOLESTEROL_HOMEOSTASIS ANTXR2
#  9 HALLMARK_CHOLESTEROL_HOMEOSTASIS ANXA13
# 10 HALLMARK_CHOLESTEROL_HOMEOSTASIS ANXA5
# # i 67 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[10]]
# # A tibble: 162 x 2
#    Pathway              Genes
#    <chr>                <chr>
#  1 HALLMARK_COAGULATION A2M
#  2 HALLMARK_COAGULATION ACOX2
#  3 HALLMARK_COAGULATION ADAM9
#  4 HALLMARK_COAGULATION ADAM9
#  5 HALLMARK_COAGULATION ANG
#  6 HALLMARK_COAGULATION ANXA1
#  7 HALLMARK_COAGULATION APOA1
#  8 HALLMARK_COAGULATION APOC1
#  9 HALLMARK_COAGULATION APOC2
# 10 HALLMARK_COAGULATION APOC3
# # i 152 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[11]]
# # A tibble: 237 x 2
#    Pathway             Genes
#    <chr>               <chr>
#  1 HALLMARK_COMPLEMENT ACTN2
#  2 HALLMARK_COMPLEMENT ADAM9
#  3 HALLMARK_COMPLEMENT ADAM9
#  4 HALLMARK_COMPLEMENT ADRA2B
#  5 HALLMARK_COMPLEMENT AKAP10
#  6 HALLMARK_COMPLEMENT ANG
#  7 HALLMARK_COMPLEMENT ANXA5
#  8 HALLMARK_COMPLEMENT APOA4
#  9 HALLMARK_COMPLEMENT APOBEC3F
# 10 HALLMARK_COMPLEMENT APOBEC3G
# # i 227 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[12]]
# # A tibble: 170 x 2
#    Pathway             Genes
#    <chr>               <chr>
#  1 HALLMARK_DNA_REPAIR AAAS
#  2 HALLMARK_DNA_REPAIR ADA
#  3 HALLMARK_DNA_REPAIR ADCY6
#  4 HALLMARK_DNA_REPAIR ADRM1
#  5 HALLMARK_DNA_REPAIR AGO4
#  6 HALLMARK_DNA_REPAIR AK1
#  7 HALLMARK_DNA_REPAIR AK3
#  8 HALLMARK_DNA_REPAIR ALYREF
#  9 HALLMARK_DNA_REPAIR APRT
# 10 HALLMARK_DNA_REPAIR ARL6IP1
# # i 160 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[13]]
# # A tibble: 218 x 2
#    Pathway              Genes
#    <chr>                <chr>
#  1 HALLMARK_E2F_TARGETS AK2
#  2 HALLMARK_E2F_TARGETS ANP32E
#  3 HALLMARK_E2F_TARGETS ASF1A
#  4 HALLMARK_E2F_TARGETS ASF1B
#  5 HALLMARK_E2F_TARGETS ASF1B
#  6 HALLMARK_E2F_TARGETS ATAD2
#  7 HALLMARK_E2F_TARGETS AURKA
#  8 HALLMARK_E2F_TARGETS AURKB
#  9 HALLMARK_E2F_TARGETS BARD1
# 10 HALLMARK_E2F_TARGETS BIRC5
# # i 208 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[14]]
# # A tibble: 204 x 2
#    Pathway                                    Genes
#    <chr>                                      <chr>
#  1 HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION ABI3BP
#  2 HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION ACTA2
#  3 HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION ADAM12
#  4 HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION ANPEP
#  5 HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION APLP1
#  6 HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION AREG
#  7 HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION BASP1
#  8 HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION BDNF
#  9 HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION BGN
# 10 HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION BMP1
# # i 194 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[15]]
# # A tibble: 216 x 2
#    Pathway                          Genes
#    <chr>                            <chr>
#  1 HALLMARK_ESTROGEN_RESPONSE_EARLY ABAT
#  2 HALLMARK_ESTROGEN_RESPONSE_EARLY ABCA3
#  3 HALLMARK_ESTROGEN_RESPONSE_EARLY ABHD2
#  4 HALLMARK_ESTROGEN_RESPONSE_EARLY ABLIM1
#  5 HALLMARK_ESTROGEN_RESPONSE_EARLY ADCY1
#  6 HALLMARK_ESTROGEN_RESPONSE_EARLY ADCY9
#  7 HALLMARK_ESTROGEN_RESPONSE_EARLY ADD3
#  8 HALLMARK_ESTROGEN_RESPONSE_EARLY AFF1
#  9 HALLMARK_ESTROGEN_RESPONSE_EARLY AKAP1
# 10 HALLMARK_ESTROGEN_RESPONSE_EARLY ALDH3B1
# # i 206 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[16]]
# # A tibble: 218 x 2
#    Pathway                         Genes
#    <chr>                           <chr>
#  1 HALLMARK_ESTROGEN_RESPONSE_LATE ABCA3
#  2 HALLMARK_ESTROGEN_RESPONSE_LATE ABHD2
#  3 HALLMARK_ESTROGEN_RESPONSE_LATE ACOX2
#  4 HALLMARK_ESTROGEN_RESPONSE_LATE ADD3
#  5 HALLMARK_ESTROGEN_RESPONSE_LATE AFF1
#  6 HALLMARK_ESTROGEN_RESPONSE_LATE AGR2
#  7 HALLMARK_ESTROGEN_RESPONSE_LATE ALDH3A2
#  8 HALLMARK_ESTROGEN_RESPONSE_LATE ALDH3B1
#  9 HALLMARK_ESTROGEN_RESPONSE_LATE AMFR
# 10 HALLMARK_ESTROGEN_RESPONSE_LATE ANXA9
# # i 208 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[17]]
# # A tibble: 165 x 2
#    Pathway                        Genes
#    <chr>                          <chr>
#  1 HALLMARK_FATTY_ACID_METABOLISM AADAT
#  2 HALLMARK_FATTY_ACID_METABOLISM ACAA1
#  3 HALLMARK_FATTY_ACID_METABOLISM ACAA2
#  4 HALLMARK_FATTY_ACID_METABOLISM ACADL
#  5 HALLMARK_FATTY_ACID_METABOLISM ACADM
#  6 HALLMARK_FATTY_ACID_METABOLISM ACADS
#  7 HALLMARK_FATTY_ACID_METABOLISM ACADVL
#  8 HALLMARK_FATTY_ACID_METABOLISM ACAT2
#  9 HALLMARK_FATTY_ACID_METABOLISM ACO2
# 10 HALLMARK_FATTY_ACID_METABOLISM ACOT2
# # i 155 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[18]]
# # A tibble: 204 x 2
#    Pathway                 Genes
#    <chr>                   <chr>
#  1 HALLMARK_G2M_CHECKPOINT ABL1
#  2 HALLMARK_G2M_CHECKPOINT AMD1
#  3 HALLMARK_G2M_CHECKPOINT ARID4A
#  4 HALLMARK_G2M_CHECKPOINT ATF5
#  5 HALLMARK_G2M_CHECKPOINT ATRX
#  6 HALLMARK_G2M_CHECKPOINT AURKA
#  7 HALLMARK_G2M_CHECKPOINT AURKB
#  8 HALLMARK_G2M_CHECKPOINT BARD1
#  9 HALLMARK_G2M_CHECKPOINT BCL3
# 10 HALLMARK_G2M_CHECKPOINT BIRC5
# # i 194 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[19]]
# # A tibble: 215 x 2
#    Pathway             Genes
#    <chr>               <chr>
#  1 HALLMARK_GLYCOLYSIS ABCB6
#  2 HALLMARK_GLYCOLYSIS ADORA2B
#  3 HALLMARK_GLYCOLYSIS AGL
#  4 HALLMARK_GLYCOLYSIS AGRN
#  5 HALLMARK_GLYCOLYSIS AK3
#  6 HALLMARK_GLYCOLYSIS AK4
#  7 HALLMARK_GLYCOLYSIS AKR1A1
#  8 HALLMARK_GLYCOLYSIS ALDH7A1
#  9 HALLMARK_GLYCOLYSIS ALDH9A1
# 10 HALLMARK_GLYCOLYSIS ALDOA
# # i 205 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[20]]
# # A tibble: 36 x 2
#    Pathway                     Genes
#    <chr>                       <chr>
#  1 HALLMARK_HEDGEHOG_SIGNALING ACHE
#  2 HALLMARK_HEDGEHOG_SIGNALING ADGRG1
#  3 HALLMARK_HEDGEHOG_SIGNALING AMOT
#  4 HALLMARK_HEDGEHOG_SIGNALING CDK5R1
#  5 HALLMARK_HEDGEHOG_SIGNALING CDK6
#  6 HALLMARK_HEDGEHOG_SIGNALING CELSR1
#  7 HALLMARK_HEDGEHOG_SIGNALING CNTFR
#  8 HALLMARK_HEDGEHOG_SIGNALING CRMP1
#  9 HALLMARK_HEDGEHOG_SIGNALING DPYSL2
# 10 HALLMARK_HEDGEHOG_SIGNALING ETS2
# # i 26 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[21]]
# # A tibble: 214 x 2
#    Pathway                  Genes
#    <chr>                    <chr>
#  1 HALLMARK_HEME_METABOLISM ABCB6
#  2 HALLMARK_HEME_METABOLISM ABCG2
#  3 HALLMARK_HEME_METABOLISM ACKR1
#  4 HALLMARK_HEME_METABOLISM ACP5
#  5 HALLMARK_HEME_METABOLISM ACSL6
#  6 HALLMARK_HEME_METABOLISM ADD1
#  7 HALLMARK_HEME_METABOLISM ADD2
#  8 HALLMARK_HEME_METABOLISM ADIPOR1
#  9 HALLMARK_HEME_METABOLISM AGPAT4
# 10 HALLMARK_HEME_METABOLISM AHSP
# # i 204 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[22]]
# # A tibble: 215 x 2
#    Pathway          Genes
#    <chr>            <chr>
#  1 HALLMARK_HYPOXIA ACKR3
#  2 HALLMARK_HYPOXIA ADM
#  3 HALLMARK_HYPOXIA ADORA2B
#  4 HALLMARK_HYPOXIA AK4
#  5 HALLMARK_HYPOXIA AKAP12
#  6 HALLMARK_HYPOXIA ALDOA
#  7 HALLMARK_HYPOXIA ALDOB
#  8 HALLMARK_HYPOXIA ALDOC
#  9 HALLMARK_HYPOXIA AMPD3
# 10 HALLMARK_HYPOXIA ANGPTL4
# # i 205 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[23]]
# # A tibble: 216 x 2
#    Pathway                      Genes
#    <chr>                        <chr>
#  1 HALLMARK_IL2_STAT5_SIGNALING ABCB1
#  2 HALLMARK_IL2_STAT5_SIGNALING ADAM19
#  3 HALLMARK_IL2_STAT5_SIGNALING AGER
#  4 HALLMARK_IL2_STAT5_SIGNALING AGER
#  5 HALLMARK_IL2_STAT5_SIGNALING AGER
#  6 HALLMARK_IL2_STAT5_SIGNALING AGER
#  7 HALLMARK_IL2_STAT5_SIGNALING AGER
#  8 HALLMARK_IL2_STAT5_SIGNALING AGER
#  9 HALLMARK_IL2_STAT5_SIGNALING AGER
# 10 HALLMARK_IL2_STAT5_SIGNALING AHCY
# # i 206 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[24]]
# # A tibble: 103 x 2
#    Pathway                          Genes
#    <chr>                            <chr>
#  1 HALLMARK_IL6_JAK_STAT3_SIGNALING A2M
#  2 HALLMARK_IL6_JAK_STAT3_SIGNALING ACVR1B
#  3 HALLMARK_IL6_JAK_STAT3_SIGNALING ACVRL1
#  4 HALLMARK_IL6_JAK_STAT3_SIGNALING BAK1
#  5 HALLMARK_IL6_JAK_STAT3_SIGNALING CBL
#  6 HALLMARK_IL6_JAK_STAT3_SIGNALING CCL7
#  7 HALLMARK_IL6_JAK_STAT3_SIGNALING CCR1
#  8 HALLMARK_IL6_JAK_STAT3_SIGNALING CD14
#  9 HALLMARK_IL6_JAK_STAT3_SIGNALING CD36
# 10 HALLMARK_IL6_JAK_STAT3_SIGNALING CD38
# # i 93 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[25]]
# # A tibble: 222 x 2
#    Pathway                        Genes
#    <chr>                          <chr>
#  1 HALLMARK_INFLAMMATORY_RESPONSE ABCA1
#  2 HALLMARK_INFLAMMATORY_RESPONSE ABI1
#  3 HALLMARK_INFLAMMATORY_RESPONSE ACVR1B
#  4 HALLMARK_INFLAMMATORY_RESPONSE ACVR2A
#  5 HALLMARK_INFLAMMATORY_RESPONSE ADGRE1
#  6 HALLMARK_INFLAMMATORY_RESPONSE ADM
#  7 HALLMARK_INFLAMMATORY_RESPONSE ADORA2B
#  8 HALLMARK_INFLAMMATORY_RESPONSE ADRM1
#  9 HALLMARK_INFLAMMATORY_RESPONSE AHR
# 10 HALLMARK_INFLAMMATORY_RESPONSE APLNR
# # i 212 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[26]]
# # A tibble: 140 x 2
#    Pathway                            Genes
#    <chr>                              <chr>
#  1 HALLMARK_INTERFERON_ALPHA_RESPONSE ADAR
#  2 HALLMARK_INTERFERON_ALPHA_RESPONSE B2M
#  3 HALLMARK_INTERFERON_ALPHA_RESPONSE B2M
#  4 HALLMARK_INTERFERON_ALPHA_RESPONSE BATF2
#  5 HALLMARK_INTERFERON_ALPHA_RESPONSE BST2
#  6 HALLMARK_INTERFERON_ALPHA_RESPONSE C1S
#  7 HALLMARK_INTERFERON_ALPHA_RESPONSE CASP1
#  8 HALLMARK_INTERFERON_ALPHA_RESPONSE CASP8
#  9 HALLMARK_INTERFERON_ALPHA_RESPONSE CCRL2
# 10 HALLMARK_INTERFERON_ALPHA_RESPONSE CD47
# # i 130 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[27]]
# # A tibble: 286 x 2
#    Pathway                            Genes
#    <chr>                              <chr>
#  1 HALLMARK_INTERFERON_GAMMA_RESPONSE ADAR
#  2 HALLMARK_INTERFERON_GAMMA_RESPONSE APOL6
#  3 HALLMARK_INTERFERON_GAMMA_RESPONSE ARID5B
#  4 HALLMARK_INTERFERON_GAMMA_RESPONSE ARL4A
#  5 HALLMARK_INTERFERON_GAMMA_RESPONSE AUTS2
#  6 HALLMARK_INTERFERON_GAMMA_RESPONSE B2M
#  7 HALLMARK_INTERFERON_GAMMA_RESPONSE B2M
#  8 HALLMARK_INTERFERON_GAMMA_RESPONSE BANK1
#  9 HALLMARK_INTERFERON_GAMMA_RESPONSE BATF2
# 10 HALLMARK_INTERFERON_GAMMA_RESPONSE BPGM
# # i 276 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[28]]
# # A tibble: 220 x 2
#    Pathway                    Genes
#    <chr>                      <chr>
#  1 HALLMARK_KRAS_SIGNALING_DN ABCB11
#  2 HALLMARK_KRAS_SIGNALING_DN ABCB11
#  3 HALLMARK_KRAS_SIGNALING_DN ABCG4
#  4 HALLMARK_KRAS_SIGNALING_DN ACTC1
#  5 HALLMARK_KRAS_SIGNALING_DN ADRA2C
#  6 HALLMARK_KRAS_SIGNALING_DN AKR1B10
#  7 HALLMARK_KRAS_SIGNALING_DN ALOX12B
#  8 HALLMARK_KRAS_SIGNALING_DN AMBN
#  9 HALLMARK_KRAS_SIGNALING_DN ARHGDIG
# 10 HALLMARK_KRAS_SIGNALING_DN ARPP21
# # i 210 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[29]]
# # A tibble: 220 x 2
#    Pathway                    Genes
#    <chr>                      <chr>
#  1 HALLMARK_KRAS_SIGNALING_UP ABCB1
#  2 HALLMARK_KRAS_SIGNALING_UP ACE
#  3 HALLMARK_KRAS_SIGNALING_UP ADAM17
#  4 HALLMARK_KRAS_SIGNALING_UP ADAM8
#  5 HALLMARK_KRAS_SIGNALING_UP ADAMDEC1
#  6 HALLMARK_KRAS_SIGNALING_UP ADGRA2
#  7 HALLMARK_KRAS_SIGNALING_UP ADGRL4
#  8 HALLMARK_KRAS_SIGNALING_UP AKAP12
#  9 HALLMARK_KRAS_SIGNALING_UP AKT2
# 10 HALLMARK_KRAS_SIGNALING_UP ALDH1A2
# # i 210 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[30]]
# # A tibble: 215 x 2
#    Pathway                  Genes
#    <chr>                    <chr>
#  1 HALLMARK_MITOTIC_SPINDLE ABI1
#  2 HALLMARK_MITOTIC_SPINDLE ABL1
#  3 HALLMARK_MITOTIC_SPINDLE ABR
#  4 HALLMARK_MITOTIC_SPINDLE ABR
#  5 HALLMARK_MITOTIC_SPINDLE ABR
#  6 HALLMARK_MITOTIC_SPINDLE ACTN4
#  7 HALLMARK_MITOTIC_SPINDLE ACTN4
#  8 HALLMARK_MITOTIC_SPINDLE AKAP13
#  9 HALLMARK_MITOTIC_SPINDLE ALMS1
# 10 HALLMARK_MITOTIC_SPINDLE ALS2
# # i 205 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[31]]
# # A tibble: 211 x 2
#    Pathway                   Genes
#    <chr>                     <chr>
#  1 HALLMARK_MTORC1_SIGNALING ABCF2
#  2 HALLMARK_MTORC1_SIGNALING ACACA
#  3 HALLMARK_MTORC1_SIGNALING ACACA
#  4 HALLMARK_MTORC1_SIGNALING ACLY
#  5 HALLMARK_MTORC1_SIGNALING ACSL3
#  6 HALLMARK_MTORC1_SIGNALING ACTR2
#  7 HALLMARK_MTORC1_SIGNALING ACTR3
#  8 HALLMARK_MTORC1_SIGNALING ADD3
#  9 HALLMARK_MTORC1_SIGNALING ADIPOR2
# 10 HALLMARK_MTORC1_SIGNALING ADIPOR2
# # i 201 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[32]]
# # A tibble: 236 x 2
#    Pathway                 Genes
#    <chr>                   <chr>
#  1 HALLMARK_MYC_TARGETS_V1 ABCE1
#  2 HALLMARK_MYC_TARGETS_V1 ACP1
#  3 HALLMARK_MYC_TARGETS_V1 AIMP2
#  4 HALLMARK_MYC_TARGETS_V1 AP3S1
#  5 HALLMARK_MYC_TARGETS_V1 APEX1
#  6 HALLMARK_MYC_TARGETS_V1 BUB3
#  7 HALLMARK_MYC_TARGETS_V1 C1QBP
#  8 HALLMARK_MYC_TARGETS_V1 CAD
#  9 HALLMARK_MYC_TARGETS_V1 CANX
# 10 HALLMARK_MYC_TARGETS_V1 CANX
# # i 226 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[33]]
# # A tibble: 60 x 2
#    Pathway                 Genes
#    <chr>                   <chr>
#  1 HALLMARK_MYC_TARGETS_V2 AIMP2
#  2 HALLMARK_MYC_TARGETS_V2 BYSL
#  3 HALLMARK_MYC_TARGETS_V2 CBX3
#  4 HALLMARK_MYC_TARGETS_V2 CDK4
#  5 HALLMARK_MYC_TARGETS_V2 DCTPP1
#  6 HALLMARK_MYC_TARGETS_V2 DDX18
#  7 HALLMARK_MYC_TARGETS_V2 DUSP2
#  8 HALLMARK_MYC_TARGETS_V2 EXOSC5
#  9 HALLMARK_MYC_TARGETS_V2 FARSA
# 10 HALLMARK_MYC_TARGETS_V2 GNL3
# # i 50 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[34]]
# # A tibble: 212 x 2
#    Pathway             Genes
#    <chr>               <chr>
#  1 HALLMARK_MYOGENESIS ABLIM1
#  2 HALLMARK_MYOGENESIS ACHE
#  3 HALLMARK_MYOGENESIS ACSL1
#  4 HALLMARK_MYOGENESIS ACTA1
#  5 HALLMARK_MYOGENESIS ACTC1
#  6 HALLMARK_MYOGENESIS ACTN2
#  7 HALLMARK_MYOGENESIS ACTN3
#  8 HALLMARK_MYOGENESIS ADAM12
#  9 HALLMARK_MYOGENESIS ADCY9
# 10 HALLMARK_MYOGENESIS AEBP1
# # i 202 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[35]]
# # A tibble: 34 x 2
#    Pathway                  Genes
#    <chr>                    <chr>
#  1 HALLMARK_NOTCH_SIGNALING APH1A
#  2 HALLMARK_NOTCH_SIGNALING ARRB1
#  3 HALLMARK_NOTCH_SIGNALING CCND1
#  4 HALLMARK_NOTCH_SIGNALING CUL1
#  5 HALLMARK_NOTCH_SIGNALING DLL1
#  6 HALLMARK_NOTCH_SIGNALING DLL1
#  7 HALLMARK_NOTCH_SIGNALING DTX1
#  8 HALLMARK_NOTCH_SIGNALING DTX2
#  9 HALLMARK_NOTCH_SIGNALING DTX2
# 10 HALLMARK_NOTCH_SIGNALING DTX4
# # i 24 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[36]]
# # A tibble: 220 x 2
#    Pathway                            Genes
#    <chr>                              <chr>
#  1 HALLMARK_OXIDATIVE_PHOSPHORYLATION ABCB7
#  2 HALLMARK_OXIDATIVE_PHOSPHORYLATION ACAA1
#  3 HALLMARK_OXIDATIVE_PHOSPHORYLATION ACAA2
#  4 HALLMARK_OXIDATIVE_PHOSPHORYLATION ACADM
#  5 HALLMARK_OXIDATIVE_PHOSPHORYLATION ACADSB
#  6 HALLMARK_OXIDATIVE_PHOSPHORYLATION ACADVL
#  7 HALLMARK_OXIDATIVE_PHOSPHORYLATION ACAT1
#  8 HALLMARK_OXIDATIVE_PHOSPHORYLATION ACO2
#  9 HALLMARK_OXIDATIVE_PHOSPHORYLATION AFG3L2
# 10 HALLMARK_OXIDATIVE_PHOSPHORYLATION AIFM1
# # i 210 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[37]]
# # A tibble: 215 x 2
#    Pathway              Genes
#    <chr>                <chr>
#  1 HALLMARK_P53_PATHWAY ABAT
#  2 HALLMARK_P53_PATHWAY ABCC5
#  3 HALLMARK_P53_PATHWAY ABHD4
#  4 HALLMARK_P53_PATHWAY ACVR1B
#  5 HALLMARK_P53_PATHWAY ADA
#  6 HALLMARK_P53_PATHWAY AEN
#  7 HALLMARK_P53_PATHWAY AK1
#  8 HALLMARK_P53_PATHWAY ALOX15B
#  9 HALLMARK_P53_PATHWAY ANKRA2
# 10 HALLMARK_P53_PATHWAY APAF1
# # i 205 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[38]]
# # A tibble: 44 x 2
#    Pathway                      Genes
#    <chr>                        <chr>
#  1 HALLMARK_PANCREAS_BETA_CELLS ABCC8
#  2 HALLMARK_PANCREAS_BETA_CELLS AKT3
#  3 HALLMARK_PANCREAS_BETA_CELLS AKT3
#  4 HALLMARK_PANCREAS_BETA_CELLS CHGA
#  5 HALLMARK_PANCREAS_BETA_CELLS CHGA
#  6 HALLMARK_PANCREAS_BETA_CELLS DCX
#  7 HALLMARK_PANCREAS_BETA_CELLS DPP4
#  8 HALLMARK_PANCREAS_BETA_CELLS ELP4
#  9 HALLMARK_PANCREAS_BETA_CELLS FOXA2
# 10 HALLMARK_PANCREAS_BETA_CELLS FOXO1
# # i 34 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[39]]
# # A tibble: 110 x 2
#    Pathway             Genes
#    <chr>               <chr>
#  1 HALLMARK_PEROXISOME ABCB1
#  2 HALLMARK_PEROXISOME ABCB4
#  3 HALLMARK_PEROXISOME ABCB9
#  4 HALLMARK_PEROXISOME ABCC5
#  5 HALLMARK_PEROXISOME ABCC8
#  6 HALLMARK_PEROXISOME ABCD1
#  7 HALLMARK_PEROXISOME ABCD2
#  8 HALLMARK_PEROXISOME ABCD3
#  9 HALLMARK_PEROXISOME ACAA1
# 10 HALLMARK_PEROXISOME ACOT8
# # i 100 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[40]]
# # A tibble: 118 x 2
#    Pathway                          Genes
#    <chr>                            <chr>
#  1 HALLMARK_PI3K_AKT_MTOR_SIGNALING ACACA
#  2 HALLMARK_PI3K_AKT_MTOR_SIGNALING ACACA
#  3 HALLMARK_PI3K_AKT_MTOR_SIGNALING ACTR2
#  4 HALLMARK_PI3K_AKT_MTOR_SIGNALING ACTR3
#  5 HALLMARK_PI3K_AKT_MTOR_SIGNALING ADCY2
#  6 HALLMARK_PI3K_AKT_MTOR_SIGNALING AKT1
#  7 HALLMARK_PI3K_AKT_MTOR_SIGNALING AKT1S1
#  8 HALLMARK_PI3K_AKT_MTOR_SIGNALING AP2M1
#  9 HALLMARK_PI3K_AKT_MTOR_SIGNALING ARF1
# 10 HALLMARK_PI3K_AKT_MTOR_SIGNALING ARHGDIA
# # i 108 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[41]]
# # A tibble: 98 x 2
#    Pathway                    Genes
#    <chr>                      <chr>
#  1 HALLMARK_PROTEIN_SECRETION ABCA1
#  2 HALLMARK_PROTEIN_SECRETION ADAM10
#  3 HALLMARK_PROTEIN_SECRETION ANP32E
#  4 HALLMARK_PROTEIN_SECRETION AP1G1
#  5 HALLMARK_PROTEIN_SECRETION AP2B1
#  6 HALLMARK_PROTEIN_SECRETION AP2M1
#  7 HALLMARK_PROTEIN_SECRETION AP2S1
#  8 HALLMARK_PROTEIN_SECRETION AP3B1
#  9 HALLMARK_PROTEIN_SECRETION AP3S1
# 10 HALLMARK_PROTEIN_SECRETION ARCN1
# # i 88 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[42]]
# # A tibble: 58 x 2
#    Pathway                                  Genes
#    <chr>                                    <chr>
#  1 HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY ABCC1
#  2 HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY ABCC1
#  3 HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY ATOX1
#  4 HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY CAT
#  5 HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY CDKN2D
#  6 HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY EGLN2
#  7 HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY ERCC2
#  8 HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY FES
#  9 HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY FTL
# 10 HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY G6PD
# # i 48 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[43]]
# # A tibble: 144 x 2
#    Pathway                  Genes
#    <chr>                    <chr>
#  1 HALLMARK_SPERMATOGENESIS ACE
#  2 HALLMARK_SPERMATOGENESIS ACRBP
#  3 HALLMARK_SPERMATOGENESIS ACRV1
#  4 HALLMARK_SPERMATOGENESIS ACTL7B
#  5 HALLMARK_SPERMATOGENESIS ADAD1
#  6 HALLMARK_SPERMATOGENESIS ADAM2
#  7 HALLMARK_SPERMATOGENESIS ADAM2
#  8 HALLMARK_SPERMATOGENESIS ADCYAP1
#  9 HALLMARK_SPERMATOGENESIS AGFG1
# 10 HALLMARK_SPERMATOGENESIS AKAP4
# # i 134 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[44]]
# # A tibble: 59 x 2
#    Pathway                     Genes
#    <chr>                       <chr>
#  1 HALLMARK_TGF_BETA_SIGNALING ACVR1
#  2 HALLMARK_TGF_BETA_SIGNALING APC
#  3 HALLMARK_TGF_BETA_SIGNALING ARID4B
#  4 HALLMARK_TGF_BETA_SIGNALING BCAR3
#  5 HALLMARK_TGF_BETA_SIGNALING BMP2
#  6 HALLMARK_TGF_BETA_SIGNALING BMPR1A
#  7 HALLMARK_TGF_BETA_SIGNALING BMPR2
#  8 HALLMARK_TGF_BETA_SIGNALING CDH1
#  9 HALLMARK_TGF_BETA_SIGNALING CDK9
# 10 HALLMARK_TGF_BETA_SIGNALING CDKN1C
# # i 49 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[45]]
# # A tibble: 228 x 2
#    Pathway                          Genes
#    <chr>                            <chr>
#  1 HALLMARK_TNFA_SIGNALING_VIA_NFKB ABCA1
#  2 HALLMARK_TNFA_SIGNALING_VIA_NFKB ACKR3
#  3 HALLMARK_TNFA_SIGNALING_VIA_NFKB AREG
#  4 HALLMARK_TNFA_SIGNALING_VIA_NFKB ATF3
#  5 HALLMARK_TNFA_SIGNALING_VIA_NFKB ATP2B1
#  6 HALLMARK_TNFA_SIGNALING_VIA_NFKB B4GALT1
#  7 HALLMARK_TNFA_SIGNALING_VIA_NFKB B4GALT5
#  8 HALLMARK_TNFA_SIGNALING_VIA_NFKB BCL2A1
#  9 HALLMARK_TNFA_SIGNALING_VIA_NFKB BCL3
# 10 HALLMARK_TNFA_SIGNALING_VIA_NFKB BCL6
# # i 218 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[46]]
# # A tibble: 115 x 2
#    Pathway                            Genes
#    <chr>                              <chr>
#  1 HALLMARK_UNFOLDED_PROTEIN_RESPONSE ALDH18A1
#  2 HALLMARK_UNFOLDED_PROTEIN_RESPONSE ARFGAP1
#  3 HALLMARK_UNFOLDED_PROTEIN_RESPONSE ASNS
#  4 HALLMARK_UNFOLDED_PROTEIN_RESPONSE ATF3
#  5 HALLMARK_UNFOLDED_PROTEIN_RESPONSE ATF4
#  6 HALLMARK_UNFOLDED_PROTEIN_RESPONSE ATF6
#  7 HALLMARK_UNFOLDED_PROTEIN_RESPONSE ATP6V0D1
#  8 HALLMARK_UNFOLDED_PROTEIN_RESPONSE BAG3
#  9 HALLMARK_UNFOLDED_PROTEIN_RESPONSE BANF1
# 10 HALLMARK_UNFOLDED_PROTEIN_RESPONSE CALR
# # i 105 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[47]]
# # A tibble: 152 x 2
#    Pathway                 Genes
#    <chr>                   <chr>
#  1 HALLMARK_UV_RESPONSE_DN ABCC1
#  2 HALLMARK_UV_RESPONSE_DN ABCC1
#  3 HALLMARK_UV_RESPONSE_DN ACVR2A
#  4 HALLMARK_UV_RESPONSE_DN ADD3
#  5 HALLMARK_UV_RESPONSE_DN ADGRL2
#  6 HALLMARK_UV_RESPONSE_DN ADORA2B
#  7 HALLMARK_UV_RESPONSE_DN AGGF1
#  8 HALLMARK_UV_RESPONSE_DN AKT3
#  9 HALLMARK_UV_RESPONSE_DN AKT3
# 10 HALLMARK_UV_RESPONSE_DN AMPH
# # i 142 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[48]]
# # A tibble: 191 x 2
#    Pathway                 Genes
#    <chr>                   <chr>
#  1 HALLMARK_UV_RESPONSE_UP ABCB1
#  2 HALLMARK_UV_RESPONSE_UP ACAA1
#  3 HALLMARK_UV_RESPONSE_UP AGO2
#  4 HALLMARK_UV_RESPONSE_UP ALAS1
#  5 HALLMARK_UV_RESPONSE_UP ALDOA
#  6 HALLMARK_UV_RESPONSE_UP AMD1
#  7 HALLMARK_UV_RESPONSE_UP AP2S1
#  8 HALLMARK_UV_RESPONSE_UP APOM
#  9 HALLMARK_UV_RESPONSE_UP APOM
# 10 HALLMARK_UV_RESPONSE_UP APOM
# # i 181 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[49]]
# # A tibble: 50 x 2
#    Pathway                             Genes
#    <chr>                               <chr>
#  1 HALLMARK_WNT_BETA_CATENIN_SIGNALING ADAM17
#  2 HALLMARK_WNT_BETA_CATENIN_SIGNALING AXIN1
#  3 HALLMARK_WNT_BETA_CATENIN_SIGNALING AXIN2
#  4 HALLMARK_WNT_BETA_CATENIN_SIGNALING CCND2
#  5 HALLMARK_WNT_BETA_CATENIN_SIGNALING CSNK1E
#  6 HALLMARK_WNT_BETA_CATENIN_SIGNALING CTNNB1
#  7 HALLMARK_WNT_BETA_CATENIN_SIGNALING CUL1
#  8 HALLMARK_WNT_BETA_CATENIN_SIGNALING DKK1
#  9 HALLMARK_WNT_BETA_CATENIN_SIGNALING DKK4
# 10 HALLMARK_WNT_BETA_CATENIN_SIGNALING DLL1
# # i 40 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[50]]
# # A tibble: 224 x 2
#    Pathway                        Genes
#    <chr>                          <chr>
#  1 HALLMARK_XENOBIOTIC_METABOLISM ABCC2
#  2 HALLMARK_XENOBIOTIC_METABOLISM ABCC3
#  3 HALLMARK_XENOBIOTIC_METABOLISM ABCD2
#  4 HALLMARK_XENOBIOTIC_METABOLISM ABHD6
#  5 HALLMARK_XENOBIOTIC_METABOLISM ACO2
#  6 HALLMARK_XENOBIOTIC_METABOLISM ACOX1
#  7 HALLMARK_XENOBIOTIC_METABOLISM ACOX2
#  8 HALLMARK_XENOBIOTIC_METABOLISM ACOX3
#  9 HALLMARK_XENOBIOTIC_METABOLISM ACP1
# 10 HALLMARK_XENOBIOTIC_METABOLISM ACP2
# # i 214 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[51]]
# # A tibble: 61 x 2
#    Pathway               Genes
#    <chr>                 <chr>
#  1 KEGG_ABC_TRANSPORTERS ABCA1
#  2 KEGG_ABC_TRANSPORTERS ABCA10
#  3 KEGG_ABC_TRANSPORTERS ABCA12
#  4 KEGG_ABC_TRANSPORTERS ABCA13
#  5 KEGG_ABC_TRANSPORTERS ABCA2
#  6 KEGG_ABC_TRANSPORTERS ABCA3
#  7 KEGG_ABC_TRANSPORTERS ABCA4
#  8 KEGG_ABC_TRANSPORTERS ABCA5
#  9 KEGG_ABC_TRANSPORTERS ABCA6
# 10 KEGG_ABC_TRANSPORTERS ABCA7
# # i 51 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[52]]
# # A tibble: 59 x 2
#    Pathway                     Genes
#    <chr>                       <chr>
#  1 KEGG_ACUTE_MYELOID_LEUKEMIA AKT1
#  2 KEGG_ACUTE_MYELOID_LEUKEMIA AKT2
#  3 KEGG_ACUTE_MYELOID_LEUKEMIA AKT3
#  4 KEGG_ACUTE_MYELOID_LEUKEMIA AKT3
#  5 KEGG_ACUTE_MYELOID_LEUKEMIA ARAF
#  6 KEGG_ACUTE_MYELOID_LEUKEMIA BAD
#  7 KEGG_ACUTE_MYELOID_LEUKEMIA BRAF
#  8 KEGG_ACUTE_MYELOID_LEUKEMIA CCNA1
#  9 KEGG_ACUTE_MYELOID_LEUKEMIA CCND1
# 10 KEGG_ACUTE_MYELOID_LEUKEMIA CEBPA
# # i 49 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[53]]
# # A tibble: 82 x 2
#    Pathway                Genes
#    <chr>                  <chr>
#  1 KEGG_ADHERENS_JUNCTION ACP1
#  2 KEGG_ADHERENS_JUNCTION ACTB
#  3 KEGG_ADHERENS_JUNCTION ACTG1
#  4 KEGG_ADHERENS_JUNCTION ACTN1
#  5 KEGG_ADHERENS_JUNCTION ACTN2
#  6 KEGG_ADHERENS_JUNCTION ACTN3
#  7 KEGG_ADHERENS_JUNCTION ACTN4
#  8 KEGG_ADHERENS_JUNCTION ACTN4
#  9 KEGG_ADHERENS_JUNCTION AFDN
# 10 KEGG_ADHERENS_JUNCTION BAIAP2
# # i 72 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[54]]
# # A tibble: 85 x 2
#    Pathway                              Genes
#    <chr>                                <chr>
#  1 KEGG_ADIPOCYTOKINE_SIGNALING_PATHWAY ACACB
#  2 KEGG_ADIPOCYTOKINE_SIGNALING_PATHWAY ACSL1
#  3 KEGG_ADIPOCYTOKINE_SIGNALING_PATHWAY ACSL3
#  4 KEGG_ADIPOCYTOKINE_SIGNALING_PATHWAY ACSL4
#  5 KEGG_ADIPOCYTOKINE_SIGNALING_PATHWAY ACSL5
#  6 KEGG_ADIPOCYTOKINE_SIGNALING_PATHWAY ACSL6
#  7 KEGG_ADIPOCYTOKINE_SIGNALING_PATHWAY ADIPOQ
#  8 KEGG_ADIPOCYTOKINE_SIGNALING_PATHWAY ADIPOR1
#  9 KEGG_ADIPOCYTOKINE_SIGNALING_PATHWAY ADIPOR2
# 10 KEGG_ADIPOCYTOKINE_SIGNALING_PATHWAY ADIPOR2
# # i 75 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[55]]
# # A tibble: 33 x 2
#    Pathway                                         Genes
#    <chr>                                           <chr>
#  1 KEGG_ALANINE_ASPARTATE_AND_GLUTAMATE_METABOLISM ABAT
#  2 KEGG_ALANINE_ASPARTATE_AND_GLUTAMATE_METABOLISM ACY3
#  3 KEGG_ALANINE_ASPARTATE_AND_GLUTAMATE_METABOLISM ADSL
#  4 KEGG_ALANINE_ASPARTATE_AND_GLUTAMATE_METABOLISM ADSS1
#  5 KEGG_ALANINE_ASPARTATE_AND_GLUTAMATE_METABOLISM ADSS2
#  6 KEGG_ALANINE_ASPARTATE_AND_GLUTAMATE_METABOLISM AGXT
#  7 KEGG_ALANINE_ASPARTATE_AND_GLUTAMATE_METABOLISM AGXT2
#  8 KEGG_ALANINE_ASPARTATE_AND_GLUTAMATE_METABOLISM ALDH4A1
#  9 KEGG_ALANINE_ASPARTATE_AND_GLUTAMATE_METABOLISM ALDH5A1
# 10 KEGG_ALANINE_ASPARTATE_AND_GLUTAMATE_METABOLISM ASL
# # i 23 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[56]]
# # A tibble: 42 x 2
#    Pathway                                        Genes
#    <chr>                                          <chr>
#  1 KEGG_ALDOSTERONE_REGULATED_SODIUM_REABSORPTION ATP1A1
#  2 KEGG_ALDOSTERONE_REGULATED_SODIUM_REABSORPTION ATP1A2
#  3 KEGG_ALDOSTERONE_REGULATED_SODIUM_REABSORPTION ATP1A3
#  4 KEGG_ALDOSTERONE_REGULATED_SODIUM_REABSORPTION ATP1A4
#  5 KEGG_ALDOSTERONE_REGULATED_SODIUM_REABSORPTION ATP1B1
#  6 KEGG_ALDOSTERONE_REGULATED_SODIUM_REABSORPTION ATP1B2
#  7 KEGG_ALDOSTERONE_REGULATED_SODIUM_REABSORPTION ATP1B3
#  8 KEGG_ALDOSTERONE_REGULATED_SODIUM_REABSORPTION ATP1B4
#  9 KEGG_ALDOSTERONE_REGULATED_SODIUM_REABSORPTION FXYD2
# 10 KEGG_ALDOSTERONE_REGULATED_SODIUM_REABSORPTION FXYD4
# # i 32 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[57]]
# # A tibble: 157 x 2
#    Pathway                  Genes
#    <chr>                    <chr>
#  1 KEGG_ALLOGRAFT_REJECTION CD28
#  2 KEGG_ALLOGRAFT_REJECTION CD40
#  3 KEGG_ALLOGRAFT_REJECTION CD40LG
#  4 KEGG_ALLOGRAFT_REJECTION CD80
#  5 KEGG_ALLOGRAFT_REJECTION CD86
#  6 KEGG_ALLOGRAFT_REJECTION FAS
#  7 KEGG_ALLOGRAFT_REJECTION FASLG
#  8 KEGG_ALLOGRAFT_REJECTION GZMB
#  9 KEGG_ALLOGRAFT_REJECTION HLA-A
# 10 KEGG_ALLOGRAFT_REJECTION HLA-A
# # i 147 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[58]]
# # A tibble: 20 x 2
#    Pathway                              Genes
#    <chr>                                <chr>
#  1 KEGG_ALPHA_LINOLENIC_ACID_METABOLISM ACOX1
#  2 KEGG_ALPHA_LINOLENIC_ACID_METABOLISM ACOX3
#  3 KEGG_ALPHA_LINOLENIC_ACID_METABOLISM FADS2
#  4 KEGG_ALPHA_LINOLENIC_ACID_METABOLISM JMJD7-PLA2G4B
#  5 KEGG_ALPHA_LINOLENIC_ACID_METABOLISM PLA2G10
#  6 KEGG_ALPHA_LINOLENIC_ACID_METABOLISM PLA2G10
#  7 KEGG_ALPHA_LINOLENIC_ACID_METABOLISM PLA2G12A
#  8 KEGG_ALPHA_LINOLENIC_ACID_METABOLISM PLA2G12B
#  9 KEGG_ALPHA_LINOLENIC_ACID_METABOLISM PLA2G1B
# 10 KEGG_ALPHA_LINOLENIC_ACID_METABOLISM PLA2G2A
# 11 KEGG_ALPHA_LINOLENIC_ACID_METABOLISM PLA2G2C
# 12 KEGG_ALPHA_LINOLENIC_ACID_METABOLISM PLA2G2D
# 13 KEGG_ALPHA_LINOLENIC_ACID_METABOLISM PLA2G2E
# 14 KEGG_ALPHA_LINOLENIC_ACID_METABOLISM PLA2G2F
# 15 KEGG_ALPHA_LINOLENIC_ACID_METABOLISM PLA2G3
# 16 KEGG_ALPHA_LINOLENIC_ACID_METABOLISM PLA2G4A
# 17 KEGG_ALPHA_LINOLENIC_ACID_METABOLISM PLA2G4B
# 18 KEGG_ALPHA_LINOLENIC_ACID_METABOLISM PLA2G4E
# 19 KEGG_ALPHA_LINOLENIC_ACID_METABOLISM PLA2G5
# 20 KEGG_ALPHA_LINOLENIC_ACID_METABOLISM PLA2G6
#
# [[59]]
# # A tibble: 193 x 2
#    Pathway                 Genes
#    <chr>                   <chr>
#  1 KEGG_ALZHEIMERS_DISEASE ADAM10
#  2 KEGG_ALZHEIMERS_DISEASE ADAM17
#  3 KEGG_ALZHEIMERS_DISEASE APAF1
#  4 KEGG_ALZHEIMERS_DISEASE APBB1
#  5 KEGG_ALZHEIMERS_DISEASE APH1A
#  6 KEGG_ALZHEIMERS_DISEASE APOE
#  7 KEGG_ALZHEIMERS_DISEASE APP
#  8 KEGG_ALZHEIMERS_DISEASE ATF6
#  9 KEGG_ALZHEIMERS_DISEASE ATP2A1
# 10 KEGG_ALZHEIMERS_DISEASE ATP2A2
# # i 183 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[60]]
# # A tibble: 55 x 2
#    Pathway                          Genes
#    <chr>                            <chr>
#  1 KEGG_AMINOACYL_TRNA_BIOSYNTHESIS AARS1
#  2 KEGG_AMINOACYL_TRNA_BIOSYNTHESIS AARS2
#  3 KEGG_AMINOACYL_TRNA_BIOSYNTHESIS CARS1
#  4 KEGG_AMINOACYL_TRNA_BIOSYNTHESIS CARS1
#  5 KEGG_AMINOACYL_TRNA_BIOSYNTHESIS CARS2
#  6 KEGG_AMINOACYL_TRNA_BIOSYNTHESIS DARS1
#  7 KEGG_AMINOACYL_TRNA_BIOSYNTHESIS DARS2
#  8 KEGG_AMINOACYL_TRNA_BIOSYNTHESIS EARS2
#  9 KEGG_AMINOACYL_TRNA_BIOSYNTHESIS EPRS1
# 10 KEGG_AMINOACYL_TRNA_BIOSYNTHESIS FARS2
# # i 45 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[61]]
# # A tibble: 46 x 2
#    Pathway                                          Genes
#    <chr>                                            <chr>
#  1 KEGG_AMINO_SUGAR_AND_NUCLEOTIDE_SUGAR_METABOLISM AMDHD2
#  2 KEGG_AMINO_SUGAR_AND_NUCLEOTIDE_SUGAR_METABOLISM CHIA
#  3 KEGG_AMINO_SUGAR_AND_NUCLEOTIDE_SUGAR_METABOLISM CHIT1
#  4 KEGG_AMINO_SUGAR_AND_NUCLEOTIDE_SUGAR_METABOLISM CMAS
#  5 KEGG_AMINO_SUGAR_AND_NUCLEOTIDE_SUGAR_METABOLISM CYB5R1
#  6 KEGG_AMINO_SUGAR_AND_NUCLEOTIDE_SUGAR_METABOLISM CYB5R3
#  7 KEGG_AMINO_SUGAR_AND_NUCLEOTIDE_SUGAR_METABOLISM FCSK
#  8 KEGG_AMINO_SUGAR_AND_NUCLEOTIDE_SUGAR_METABOLISM FPGT
#  9 KEGG_AMINO_SUGAR_AND_NUCLEOTIDE_SUGAR_METABOLISM GALE
# 10 KEGG_AMINO_SUGAR_AND_NUCLEOTIDE_SUGAR_METABOLISM GALK1
# # i 36 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[62]]
# # A tibble: 65 x 2
#    Pathway                                Genes
#    <chr>                                  <chr>
#  1 KEGG_AMYOTROPHIC_LATERAL_SCLEROSIS_ALS ALS2
#  2 KEGG_AMYOTROPHIC_LATERAL_SCLEROSIS_ALS APAF1
#  3 KEGG_AMYOTROPHIC_LATERAL_SCLEROSIS_ALS BAD
#  4 KEGG_AMYOTROPHIC_LATERAL_SCLEROSIS_ALS BAX
#  5 KEGG_AMYOTROPHIC_LATERAL_SCLEROSIS_ALS BCL2
#  6 KEGG_AMYOTROPHIC_LATERAL_SCLEROSIS_ALS BCL2L1
#  7 KEGG_AMYOTROPHIC_LATERAL_SCLEROSIS_ALS BID
#  8 KEGG_AMYOTROPHIC_LATERAL_SCLEROSIS_ALS CASP1
#  9 KEGG_AMYOTROPHIC_LATERAL_SCLEROSIS_ALS CASP3
# 10 KEGG_AMYOTROPHIC_LATERAL_SCLEROSIS_ALS CASP9
# # i 55 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[63]]
# # A tibble: 535 x 2
#    Pathway                                  Genes
#    <chr>                                    <chr>
#  1 KEGG_ANTIGEN_PROCESSING_AND_PRESENTATION B2M
#  2 KEGG_ANTIGEN_PROCESSING_AND_PRESENTATION B2M
#  3 KEGG_ANTIGEN_PROCESSING_AND_PRESENTATION CALR
#  4 KEGG_ANTIGEN_PROCESSING_AND_PRESENTATION CANX
#  5 KEGG_ANTIGEN_PROCESSING_AND_PRESENTATION CANX
#  6 KEGG_ANTIGEN_PROCESSING_AND_PRESENTATION CD4
#  7 KEGG_ANTIGEN_PROCESSING_AND_PRESENTATION CD74
#  8 KEGG_ANTIGEN_PROCESSING_AND_PRESENTATION CD8A
#  9 KEGG_ANTIGEN_PROCESSING_AND_PRESENTATION CD8B
# 10 KEGG_ANTIGEN_PROCESSING_AND_PRESENTATION CIITA
# # i 525 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[64]]
# # A tibble: 98 x 2
#    Pathway        Genes
#    <chr>          <chr>
#  1 KEGG_APOPTOSIS AIFM1
#  2 KEGG_APOPTOSIS AKT1
#  3 KEGG_APOPTOSIS AKT2
#  4 KEGG_APOPTOSIS AKT3
#  5 KEGG_APOPTOSIS AKT3
#  6 KEGG_APOPTOSIS APAF1
#  7 KEGG_APOPTOSIS ATM
#  8 KEGG_APOPTOSIS BAD
#  9 KEGG_APOPTOSIS BAX
# 10 KEGG_APOPTOSIS BCL2
# # i 88 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[65]]
# # A tibble: 64 x 2
#    Pathway                          Genes
#    <chr>                            <chr>
#  1 KEGG_ARACHIDONIC_ACID_METABOLISM AKR1C3
#  2 KEGG_ARACHIDONIC_ACID_METABOLISM ALOX12
#  3 KEGG_ARACHIDONIC_ACID_METABOLISM ALOX12B
#  4 KEGG_ARACHIDONIC_ACID_METABOLISM ALOX15
#  5 KEGG_ARACHIDONIC_ACID_METABOLISM ALOX15B
#  6 KEGG_ARACHIDONIC_ACID_METABOLISM ALOX5
#  7 KEGG_ARACHIDONIC_ACID_METABOLISM ALOX5
#  8 KEGG_ARACHIDONIC_ACID_METABOLISM CBR1
#  9 KEGG_ARACHIDONIC_ACID_METABOLISM CBR3
# 10 KEGG_ARACHIDONIC_ACID_METABOLISM CYP2B6
# # i 54 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[66]]
# # A tibble: 56 x 2
#    Pathway                              Genes
#    <chr>                                <chr>
#  1 KEGG_ARGININE_AND_PROLINE_METABOLISM ACY1
#  2 KEGG_ARGININE_AND_PROLINE_METABOLISM AGMAT
#  3 KEGG_ARGININE_AND_PROLINE_METABOLISM ALDH18A1
#  4 KEGG_ARGININE_AND_PROLINE_METABOLISM ALDH1B1
#  5 KEGG_ARGININE_AND_PROLINE_METABOLISM ALDH2
#  6 KEGG_ARGININE_AND_PROLINE_METABOLISM ALDH3A2
#  7 KEGG_ARGININE_AND_PROLINE_METABOLISM ALDH4A1
#  8 KEGG_ARGININE_AND_PROLINE_METABOLISM ALDH7A1
#  9 KEGG_ARGININE_AND_PROLINE_METABOLISM ALDH9A1
# 10 KEGG_ARGININE_AND_PROLINE_METABOLISM AMD1
# # i 46 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[67]]
# # A tibble: 77 x 2
#    Pathway                                                   Genes
#    <chr>                                                     <chr>
#  1 KEGG_ARRHYTHMOGENIC_RIGHT_VENTRICULAR_CARDIOMYOPATHY_ARVC ACTB
#  2 KEGG_ARRHYTHMOGENIC_RIGHT_VENTRICULAR_CARDIOMYOPATHY_ARVC ACTG1
#  3 KEGG_ARRHYTHMOGENIC_RIGHT_VENTRICULAR_CARDIOMYOPATHY_ARVC ACTN1
#  4 KEGG_ARRHYTHMOGENIC_RIGHT_VENTRICULAR_CARDIOMYOPATHY_ARVC ACTN2
#  5 KEGG_ARRHYTHMOGENIC_RIGHT_VENTRICULAR_CARDIOMYOPATHY_ARVC ACTN3
#  6 KEGG_ARRHYTHMOGENIC_RIGHT_VENTRICULAR_CARDIOMYOPATHY_ARVC ACTN4
#  7 KEGG_ARRHYTHMOGENIC_RIGHT_VENTRICULAR_CARDIOMYOPATHY_ARVC ACTN4
#  8 KEGG_ARRHYTHMOGENIC_RIGHT_VENTRICULAR_CARDIOMYOPATHY_ARVC ATP2A2
#  9 KEGG_ARRHYTHMOGENIC_RIGHT_VENTRICULAR_CARDIOMYOPATHY_ARVC CACNA1C
# 10 KEGG_ARRHYTHMOGENIC_RIGHT_VENTRICULAR_CARDIOMYOPATHY_ARVC CACNA1C
# # i 67 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[68]]
# # A tibble: 28 x 2
#    Pathway                                Genes
#    <chr>                                  <chr>
#  1 KEGG_ASCORBATE_AND_ALDARATE_METABOLISM ALDH1B1
#  2 KEGG_ASCORBATE_AND_ALDARATE_METABOLISM ALDH2
#  3 KEGG_ASCORBATE_AND_ALDARATE_METABOLISM ALDH3A2
#  4 KEGG_ASCORBATE_AND_ALDARATE_METABOLISM ALDH7A1
#  5 KEGG_ASCORBATE_AND_ALDARATE_METABOLISM ALDH9A1
#  6 KEGG_ASCORBATE_AND_ALDARATE_METABOLISM MIOX
#  7 KEGG_ASCORBATE_AND_ALDARATE_METABOLISM UGDH
#  8 KEGG_ASCORBATE_AND_ALDARATE_METABOLISM UGT1A1
#  9 KEGG_ASCORBATE_AND_ALDARATE_METABOLISM UGT1A10
# 10 KEGG_ASCORBATE_AND_ALDARATE_METABOLISM UGT1A3
# # i 18 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[69]]
# # A tibble: 113 x 2
#    Pathway     Genes
#    <chr>       <chr>
#  1 KEGG_ASTHMA CCL11
#  2 KEGG_ASTHMA CD40
#  3 KEGG_ASTHMA CD40LG
#  4 KEGG_ASTHMA EPX
#  5 KEGG_ASTHMA FCER1A
#  6 KEGG_ASTHMA FCER1G
#  7 KEGG_ASTHMA HLA-DMA
#  8 KEGG_ASTHMA HLA-DMA
#  9 KEGG_ASTHMA HLA-DMA
# 10 KEGG_ASTHMA HLA-DMA
# # i 103 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[70]]
# # A tibble: 166 x 2
#    Pathway                         Genes
#    <chr>                           <chr>
#  1 KEGG_AUTOIMMUNE_THYROID_DISEASE CD28
#  2 KEGG_AUTOIMMUNE_THYROID_DISEASE CD40
#  3 KEGG_AUTOIMMUNE_THYROID_DISEASE CD40LG
#  4 KEGG_AUTOIMMUNE_THYROID_DISEASE CD80
#  5 KEGG_AUTOIMMUNE_THYROID_DISEASE CD86
#  6 KEGG_AUTOIMMUNE_THYROID_DISEASE CGA
#  7 KEGG_AUTOIMMUNE_THYROID_DISEASE CTLA4
#  8 KEGG_AUTOIMMUNE_THYROID_DISEASE FAS
#  9 KEGG_AUTOIMMUNE_THYROID_DISEASE FASLG
# 10 KEGG_AUTOIMMUNE_THYROID_DISEASE GZMB
# # i 156 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[71]]
# # A tibble: 134 x 2
#    Pathway            Genes
#    <chr>              <chr>
#  1 KEGG_AXON_GUIDANCE ABL1
#  2 KEGG_AXON_GUIDANCE ABLIM1
#  3 KEGG_AXON_GUIDANCE ABLIM2
#  4 KEGG_AXON_GUIDANCE ABLIM3
#  5 KEGG_AXON_GUIDANCE ARHGEF12
#  6 KEGG_AXON_GUIDANCE CDC42
#  7 KEGG_AXON_GUIDANCE CDK5
#  8 KEGG_AXON_GUIDANCE CFL1
#  9 KEGG_AXON_GUIDANCE CFL2
# 10 KEGG_AXON_GUIDANCE CHP1
# # i 124 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[72]]
# # A tibble: 58 x 2
#    Pathway                   Genes
#    <chr>                     <chr>
#  1 KEGG_BASAL_CELL_CARCINOMA APC
#  2 KEGG_BASAL_CELL_CARCINOMA APC2
#  3 KEGG_BASAL_CELL_CARCINOMA AXIN1
#  4 KEGG_BASAL_CELL_CARCINOMA AXIN2
#  5 KEGG_BASAL_CELL_CARCINOMA BMP2
#  6 KEGG_BASAL_CELL_CARCINOMA BMP4
#  7 KEGG_BASAL_CELL_CARCINOMA CTNNB1
#  8 KEGG_BASAL_CELL_CARCINOMA DVL1
#  9 KEGG_BASAL_CELL_CARCINOMA DVL2
# 10 KEGG_BASAL_CELL_CARCINOMA DVL3
# # i 48 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[73]]
# # A tibble: 45 x 2
#    Pathway                          Genes
#    <chr>                            <chr>
#  1 KEGG_BASAL_TRANSCRIPTION_FACTORS GTF2A1
#  2 KEGG_BASAL_TRANSCRIPTION_FACTORS GTF2A1L
#  3 KEGG_BASAL_TRANSCRIPTION_FACTORS GTF2A2
#  4 KEGG_BASAL_TRANSCRIPTION_FACTORS GTF2B
#  5 KEGG_BASAL_TRANSCRIPTION_FACTORS GTF2E1
#  6 KEGG_BASAL_TRANSCRIPTION_FACTORS GTF2E2
#  7 KEGG_BASAL_TRANSCRIPTION_FACTORS GTF2F1
#  8 KEGG_BASAL_TRANSCRIPTION_FACTORS GTF2F2
#  9 KEGG_BASAL_TRANSCRIPTION_FACTORS GTF2H1
# 10 KEGG_BASAL_TRANSCRIPTION_FACTORS GTF2H1
# # i 35 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[74]]
# # A tibble: 35 x 2
#    Pathway                   Genes
#    <chr>                     <chr>
#  1 KEGG_BASE_EXCISION_REPAIR APEX1
#  2 KEGG_BASE_EXCISION_REPAIR APEX2
#  3 KEGG_BASE_EXCISION_REPAIR FEN1
#  4 KEGG_BASE_EXCISION_REPAIR HMGB1
#  5 KEGG_BASE_EXCISION_REPAIR HMGB1P1
#  6 KEGG_BASE_EXCISION_REPAIR HMGB1P40
#  7 KEGG_BASE_EXCISION_REPAIR LIG1
#  8 KEGG_BASE_EXCISION_REPAIR LIG3
#  9 KEGG_BASE_EXCISION_REPAIR MBD4
# 10 KEGG_BASE_EXCISION_REPAIR MPG
# # i 25 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[75]]
# # A tibble: 22 x 2
#    Pathway                      Genes
#    <chr>                        <chr>
#  1 KEGG_BETA_ALANINE_METABOLISM ABAT
#  2 KEGG_BETA_ALANINE_METABOLISM ACADM
#  3 KEGG_BETA_ALANINE_METABOLISM ALDH1B1
#  4 KEGG_BETA_ALANINE_METABOLISM ALDH2
#  5 KEGG_BETA_ALANINE_METABOLISM ALDH3A2
#  6 KEGG_BETA_ALANINE_METABOLISM ALDH7A1
#  7 KEGG_BETA_ALANINE_METABOLISM ALDH9A1
#  8 KEGG_BETA_ALANINE_METABOLISM AOC2
#  9 KEGG_BETA_ALANINE_METABOLISM AOC3
# 10 KEGG_BETA_ALANINE_METABOLISM CNDP1
# # i 12 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[76]]
# # A tibble: 23 x 2
#    Pathway                                      Genes
#    <chr>                                        <chr>
#  1 KEGG_BIOSYNTHESIS_OF_UNSATURATED_FATTY_ACIDS ACAA1
#  2 KEGG_BIOSYNTHESIS_OF_UNSATURATED_FATTY_ACIDS ACOT1
#  3 KEGG_BIOSYNTHESIS_OF_UNSATURATED_FATTY_ACIDS ACOT2
#  4 KEGG_BIOSYNTHESIS_OF_UNSATURATED_FATTY_ACIDS ACOT4
#  5 KEGG_BIOSYNTHESIS_OF_UNSATURATED_FATTY_ACIDS ACOT7
#  6 KEGG_BIOSYNTHESIS_OF_UNSATURATED_FATTY_ACIDS ACOX1
#  7 KEGG_BIOSYNTHESIS_OF_UNSATURATED_FATTY_ACIDS ACOX3
#  8 KEGG_BIOSYNTHESIS_OF_UNSATURATED_FATTY_ACIDS BAAT
#  9 KEGG_BIOSYNTHESIS_OF_UNSATURATED_FATTY_ACIDS BAAT
# 10 KEGG_BIOSYNTHESIS_OF_UNSATURATED_FATTY_ACIDS ELOVL2
# # i 13 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[77]]
# # A tibble: 45 x 2
#    Pathway             Genes
#    <chr>               <chr>
#  1 KEGG_BLADDER_CANCER ARAF
#  2 KEGG_BLADDER_CANCER BRAF
#  3 KEGG_BLADDER_CANCER CCND1
#  4 KEGG_BLADDER_CANCER CDH1
#  5 KEGG_BLADDER_CANCER CDK4
#  6 KEGG_BLADDER_CANCER CDKN1A
#  7 KEGG_BLADDER_CANCER CDKN2A
#  8 KEGG_BLADDER_CANCER CXCL8
#  9 KEGG_BLADDER_CANCER DAPK1
# 10 KEGG_BLADDER_CANCER DAPK2
# # i 35 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[78]]
# # A tibble: 35 x 2
#    Pathway                   Genes
#    <chr>                     <chr>
#  1 KEGG_BUTANOATE_METABOLISM AACS
#  2 KEGG_BUTANOATE_METABOLISM ABAT
#  3 KEGG_BUTANOATE_METABOLISM ACADS
#  4 KEGG_BUTANOATE_METABOLISM ACAT1
#  5 KEGG_BUTANOATE_METABOLISM ACAT2
#  6 KEGG_BUTANOATE_METABOLISM ACSM1
#  7 KEGG_BUTANOATE_METABOLISM ACSM2A
#  8 KEGG_BUTANOATE_METABOLISM ACSM3
#  9 KEGG_BUTANOATE_METABOLISM ACSM4
# 10 KEGG_BUTANOATE_METABOLISM ACSM5
# # i 25 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[79]]
# # A tibble: 83 x 2
#    Pathway                                Genes
#    <chr>                                  <chr>
#  1 KEGG_B_CELL_RECEPTOR_SIGNALING_PATHWAY AKT1
#  2 KEGG_B_CELL_RECEPTOR_SIGNALING_PATHWAY AKT2
#  3 KEGG_B_CELL_RECEPTOR_SIGNALING_PATHWAY AKT3
#  4 KEGG_B_CELL_RECEPTOR_SIGNALING_PATHWAY AKT3
#  5 KEGG_B_CELL_RECEPTOR_SIGNALING_PATHWAY BCL10
#  6 KEGG_B_CELL_RECEPTOR_SIGNALING_PATHWAY BLNK
#  7 KEGG_B_CELL_RECEPTOR_SIGNALING_PATHWAY BTK
#  8 KEGG_B_CELL_RECEPTOR_SIGNALING_PATHWAY CARD11
#  9 KEGG_B_CELL_RECEPTOR_SIGNALING_PATHWAY CD19
# 10 KEGG_B_CELL_RECEPTOR_SIGNALING_PATHWAY CD22
# # i 73 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[80]]
# # A tibble: 185 x 2
#    Pathway                        Genes
#    <chr>                          <chr>
#  1 KEGG_CALCIUM_SIGNALING_PATHWAY ADCY1
#  2 KEGG_CALCIUM_SIGNALING_PATHWAY ADCY2
#  3 KEGG_CALCIUM_SIGNALING_PATHWAY ADCY3
#  4 KEGG_CALCIUM_SIGNALING_PATHWAY ADCY4
#  5 KEGG_CALCIUM_SIGNALING_PATHWAY ADCY4
#  6 KEGG_CALCIUM_SIGNALING_PATHWAY ADCY7
#  7 KEGG_CALCIUM_SIGNALING_PATHWAY ADCY8
#  8 KEGG_CALCIUM_SIGNALING_PATHWAY ADCY9
#  9 KEGG_CALCIUM_SIGNALING_PATHWAY ADORA2A
# 10 KEGG_CALCIUM_SIGNALING_PATHWAY ADORA2B
# # i 175 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[81]]
# # A tibble: 83 x 2
#    Pathway                         Genes
#    <chr>                           <chr>
#  1 KEGG_CARDIAC_MUSCLE_CONTRACTION ACTC1
#  2 KEGG_CARDIAC_MUSCLE_CONTRACTION ATP1A1
#  3 KEGG_CARDIAC_MUSCLE_CONTRACTION ATP1A2
#  4 KEGG_CARDIAC_MUSCLE_CONTRACTION ATP1A3
#  5 KEGG_CARDIAC_MUSCLE_CONTRACTION ATP1A4
#  6 KEGG_CARDIAC_MUSCLE_CONTRACTION ATP1B1
#  7 KEGG_CARDIAC_MUSCLE_CONTRACTION ATP1B2
#  8 KEGG_CARDIAC_MUSCLE_CONTRACTION ATP1B3
#  9 KEGG_CARDIAC_MUSCLE_CONTRACTION ATP1B4
# 10 KEGG_CARDIAC_MUSCLE_CONTRACTION ATP2A2
# # i 73 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[82]]
# # A tibble: 255 x 2
#    Pathway                           Genes
#    <chr>                             <chr>
#  1 KEGG_CELL_ADHESION_MOLECULES_CAMS ALCAM
#  2 KEGG_CELL_ADHESION_MOLECULES_CAMS CADM1
#  3 KEGG_CELL_ADHESION_MOLECULES_CAMS CADM3
#  4 KEGG_CELL_ADHESION_MOLECULES_CAMS CD2
#  5 KEGG_CELL_ADHESION_MOLECULES_CAMS CD22
#  6 KEGG_CELL_ADHESION_MOLECULES_CAMS CD226
#  7 KEGG_CELL_ADHESION_MOLECULES_CAMS CD274
#  8 KEGG_CELL_ADHESION_MOLECULES_CAMS CD276
#  9 KEGG_CELL_ADHESION_MOLECULES_CAMS CD28
# 10 KEGG_CELL_ADHESION_MOLECULES_CAMS CD34
# # i 245 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[83]]
# # A tibble: 130 x 2
#    Pathway         Genes
#    <chr>           <chr>
#  1 KEGG_CELL_CYCLE ABL1
#  2 KEGG_CELL_CYCLE ANAPC1
#  3 KEGG_CELL_CYCLE ANAPC10
#  4 KEGG_CELL_CYCLE ANAPC11
#  5 KEGG_CELL_CYCLE ANAPC13
#  6 KEGG_CELL_CYCLE ANAPC2
#  7 KEGG_CELL_CYCLE ANAPC4
#  8 KEGG_CELL_CYCLE ANAPC5
#  9 KEGG_CELL_CYCLE ANAPC7
# 10 KEGG_CELL_CYCLE ATM
# # i 120 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[84]]
# # A tibble: 214 x 2
#    Pathway                          Genes
#    <chr>                            <chr>
#  1 KEGG_CHEMOKINE_SIGNALING_PATHWAY ADCY1
#  2 KEGG_CHEMOKINE_SIGNALING_PATHWAY ADCY2
#  3 KEGG_CHEMOKINE_SIGNALING_PATHWAY ADCY3
#  4 KEGG_CHEMOKINE_SIGNALING_PATHWAY ADCY4
#  5 KEGG_CHEMOKINE_SIGNALING_PATHWAY ADCY4
#  6 KEGG_CHEMOKINE_SIGNALING_PATHWAY ADCY5
#  7 KEGG_CHEMOKINE_SIGNALING_PATHWAY ADCY6
#  8 KEGG_CHEMOKINE_SIGNALING_PATHWAY ADCY7
#  9 KEGG_CHEMOKINE_SIGNALING_PATHWAY ADCY8
# 10 KEGG_CHEMOKINE_SIGNALING_PATHWAY ADCY9
# # i 204 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[85]]
# # A tibble: 76 x 2
#    Pathway                       Genes
#    <chr>                         <chr>
#  1 KEGG_CHRONIC_MYELOID_LEUKEMIA ABL1
#  2 KEGG_CHRONIC_MYELOID_LEUKEMIA AKT1
#  3 KEGG_CHRONIC_MYELOID_LEUKEMIA AKT2
# ...
# 4 REACTOME_SEROTONIN_AND_MELATONIN_BIOSYNTHESIS TPH1
# 5 REACTOME_SEROTONIN_AND_MELATONIN_BIOSYNTHESIS TPH2
#
# [[1504]]
# # A tibble: 18 x 2
#    Pathway                                           Genes
#    <chr>                                             <chr>
#  1 REACTOME_SEROTONIN_NEUROTRANSMITTER_RELEASE_CYCLE CPLX1
#  2 REACTOME_SEROTONIN_NEUROTRANSMITTER_RELEASE_CYCLE PPFIA1
#  3 REACTOME_SEROTONIN_NEUROTRANSMITTER_RELEASE_CYCLE PPFIA2
#  4 REACTOME_SEROTONIN_NEUROTRANSMITTER_RELEASE_CYCLE PPFIA3
#  5 REACTOME_SEROTONIN_NEUROTRANSMITTER_RELEASE_CYCLE PPFIA4
#  6 REACTOME_SEROTONIN_NEUROTRANSMITTER_RELEASE_CYCLE RAB3A
#  7 REACTOME_SEROTONIN_NEUROTRANSMITTER_RELEASE_CYCLE RIMS1
#  8 REACTOME_SEROTONIN_NEUROTRANSMITTER_RELEASE_CYCLE SLC18A2
#  9 REACTOME_SEROTONIN_NEUROTRANSMITTER_RELEASE_CYCLE SNAP25
# 10 REACTOME_SEROTONIN_NEUROTRANSMITTER_RELEASE_CYCLE STX1A
# 11 REACTOME_SEROTONIN_NEUROTRANSMITTER_RELEASE_CYCLE STXBP1
# 12 REACTOME_SEROTONIN_NEUROTRANSMITTER_RELEASE_CYCLE SYN1
# 13 REACTOME_SEROTONIN_NEUROTRANSMITTER_RELEASE_CYCLE SYN2
# 14 REACTOME_SEROTONIN_NEUROTRANSMITTER_RELEASE_CYCLE SYN3
# 15 REACTOME_SEROTONIN_NEUROTRANSMITTER_RELEASE_CYCLE SYT1
# 16 REACTOME_SEROTONIN_NEUROTRANSMITTER_RELEASE_CYCLE TSPOAP1
# 17 REACTOME_SEROTONIN_NEUROTRANSMITTER_RELEASE_CYCLE UNC13B
# 18 REACTOME_SEROTONIN_NEUROTRANSMITTER_RELEASE_CYCLE VAMP2
#
# [[1505]]
# # A tibble: 12 x 2
#    Pathway                      Genes
#    <chr>                        <chr>
#  1 REACTOME_SEROTONIN_RECEPTORS HTR1A
#  2 REACTOME_SEROTONIN_RECEPTORS HTR1B
#  3 REACTOME_SEROTONIN_RECEPTORS HTR1D
#  4 REACTOME_SEROTONIN_RECEPTORS HTR1E
#  5 REACTOME_SEROTONIN_RECEPTORS HTR1F
#  6 REACTOME_SEROTONIN_RECEPTORS HTR2A
#  7 REACTOME_SEROTONIN_RECEPTORS HTR2B
#  8 REACTOME_SEROTONIN_RECEPTORS HTR2C
#  9 REACTOME_SEROTONIN_RECEPTORS HTR4
# 10 REACTOME_SEROTONIN_RECEPTORS HTR5A
# 11 REACTOME_SEROTONIN_RECEPTORS HTR6
# 12 REACTOME_SEROTONIN_RECEPTORS HTR7
#
# [[1506]]
# # A tibble: 15 x 2
#    Pathway                                Genes
#    <chr>                                  <chr>
#  1 REACTOME_SHC1_EVENTS_IN_EGFR_SIGNALING AREG
#  2 REACTOME_SHC1_EVENTS_IN_EGFR_SIGNALING BTC
#  3 REACTOME_SHC1_EVENTS_IN_EGFR_SIGNALING EGF
#  4 REACTOME_SHC1_EVENTS_IN_EGFR_SIGNALING EGFR
#  5 REACTOME_SHC1_EVENTS_IN_EGFR_SIGNALING EPGN
#  6 REACTOME_SHC1_EVENTS_IN_EGFR_SIGNALING EREG
#  7 REACTOME_SHC1_EVENTS_IN_EGFR_SIGNALING GRB2
#  8 REACTOME_SHC1_EVENTS_IN_EGFR_SIGNALING HBEGF
#  9 REACTOME_SHC1_EVENTS_IN_EGFR_SIGNALING HRAS
# 10 REACTOME_SHC1_EVENTS_IN_EGFR_SIGNALING HRAS
# 11 REACTOME_SHC1_EVENTS_IN_EGFR_SIGNALING KRAS
# 12 REACTOME_SHC1_EVENTS_IN_EGFR_SIGNALING NRAS
# 13 REACTOME_SHC1_EVENTS_IN_EGFR_SIGNALING SHC1
# 14 REACTOME_SHC1_EVENTS_IN_EGFR_SIGNALING SOS1
# 15 REACTOME_SHC1_EVENTS_IN_EGFR_SIGNALING TGFA
#
# [[1507]]
# # A tibble: 23 x 2
#    Pathway                                 Genes
#    <chr>                                   <chr>
#  1 REACTOME_SHC1_EVENTS_IN_ERBB2_SIGNALING BTC
#  2 REACTOME_SHC1_EVENTS_IN_ERBB2_SIGNALING EGF
#  3 REACTOME_SHC1_EVENTS_IN_ERBB2_SIGNALING EGFR
#  4 REACTOME_SHC1_EVENTS_IN_ERBB2_SIGNALING ERBB2
#  5 REACTOME_SHC1_EVENTS_IN_ERBB2_SIGNALING ERBB3
#  6 REACTOME_SHC1_EVENTS_IN_ERBB2_SIGNALING ERBB4
#  7 REACTOME_SHC1_EVENTS_IN_ERBB2_SIGNALING EREG
#  8 REACTOME_SHC1_EVENTS_IN_ERBB2_SIGNALING GRB2
#  9 REACTOME_SHC1_EVENTS_IN_ERBB2_SIGNALING HBEGF
# 10 REACTOME_SHC1_EVENTS_IN_ERBB2_SIGNALING HRAS
# # i 13 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[1508]]
# # A tibble: 15 x 2
#    Pathway                                 Genes
#    <chr>                                   <chr>
#  1 REACTOME_SHC1_EVENTS_IN_ERBB4_SIGNALING BTC
#  2 REACTOME_SHC1_EVENTS_IN_ERBB4_SIGNALING ERBB4
#  3 REACTOME_SHC1_EVENTS_IN_ERBB4_SIGNALING EREG
#  4 REACTOME_SHC1_EVENTS_IN_ERBB4_SIGNALING GRB2
#  5 REACTOME_SHC1_EVENTS_IN_ERBB4_SIGNALING HBEGF
#  6 REACTOME_SHC1_EVENTS_IN_ERBB4_SIGNALING HRAS
#  7 REACTOME_SHC1_EVENTS_IN_ERBB4_SIGNALING HRAS
#  8 REACTOME_SHC1_EVENTS_IN_ERBB4_SIGNALING KRAS
#  9 REACTOME_SHC1_EVENTS_IN_ERBB4_SIGNALING NRAS
# 10 REACTOME_SHC1_EVENTS_IN_ERBB4_SIGNALING NRG1
# 11 REACTOME_SHC1_EVENTS_IN_ERBB4_SIGNALING NRG2
# 12 REACTOME_SHC1_EVENTS_IN_ERBB4_SIGNALING NRG3
# 13 REACTOME_SHC1_EVENTS_IN_ERBB4_SIGNALING NRG4
# 14 REACTOME_SHC1_EVENTS_IN_ERBB4_SIGNALING SHC1
# 15 REACTOME_SHC1_EVENTS_IN_ERBB4_SIGNALING SOS1
#
# [[1509]]
# # A tibble: 22 x 2
#    Pathway                             Genes
#    <chr>                               <chr>
#  1 REACTOME_SHC_MEDIATED_CASCADE_FGFR1 FGF1
#  2 REACTOME_SHC_MEDIATED_CASCADE_FGFR1 FGF10
#  3 REACTOME_SHC_MEDIATED_CASCADE_FGFR1 FGF17
#  4 REACTOME_SHC_MEDIATED_CASCADE_FGFR1 FGF2
#  5 REACTOME_SHC_MEDIATED_CASCADE_FGFR1 FGF20
#  6 REACTOME_SHC_MEDIATED_CASCADE_FGFR1 FGF22
#  7 REACTOME_SHC_MEDIATED_CASCADE_FGFR1 FGF23
#  8 REACTOME_SHC_MEDIATED_CASCADE_FGFR1 FGF3
#  9 REACTOME_SHC_MEDIATED_CASCADE_FGFR1 FGF4
# 10 REACTOME_SHC_MEDIATED_CASCADE_FGFR1 FGF5
# # i 12 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[1510]]
# # A tibble: 19 x 2
#    Pathway                             Genes
#    <chr>                               <chr>
#  1 REACTOME_SHC_MEDIATED_CASCADE_FGFR3 FGF1
#  2 REACTOME_SHC_MEDIATED_CASCADE_FGFR3 FGF16
#  3 REACTOME_SHC_MEDIATED_CASCADE_FGFR3 FGF17
#  4 REACTOME_SHC_MEDIATED_CASCADE_FGFR3 FGF18
#  5 REACTOME_SHC_MEDIATED_CASCADE_FGFR3 FGF2
#  6 REACTOME_SHC_MEDIATED_CASCADE_FGFR3 FGF20
#  7 REACTOME_SHC_MEDIATED_CASCADE_FGFR3 FGF23
#  8 REACTOME_SHC_MEDIATED_CASCADE_FGFR3 FGF4
#  9 REACTOME_SHC_MEDIATED_CASCADE_FGFR3 FGF5
# 10 REACTOME_SHC_MEDIATED_CASCADE_FGFR3 FGF8
# 11 REACTOME_SHC_MEDIATED_CASCADE_FGFR3 FGF9
# 12 REACTOME_SHC_MEDIATED_CASCADE_FGFR3 FGFR3
# 13 REACTOME_SHC_MEDIATED_CASCADE_FGFR3 GRB2
# 14 REACTOME_SHC_MEDIATED_CASCADE_FGFR3 HRAS
# 15 REACTOME_SHC_MEDIATED_CASCADE_FGFR3 HRAS
# 16 REACTOME_SHC_MEDIATED_CASCADE_FGFR3 KRAS
# 17 REACTOME_SHC_MEDIATED_CASCADE_FGFR3 NRAS
# 18 REACTOME_SHC_MEDIATED_CASCADE_FGFR3 SHC1
# 19 REACTOME_SHC_MEDIATED_CASCADE_FGFR3 SOS1
#
# [[1511]]
# # A tibble: 21 x 2
#    Pathway                             Genes
#    <chr>                               <chr>
#  1 REACTOME_SHC_MEDIATED_CASCADE_FGFR4 FGF1
#  2 REACTOME_SHC_MEDIATED_CASCADE_FGFR4 FGF16
#  3 REACTOME_SHC_MEDIATED_CASCADE_FGFR4 FGF17
#  4 REACTOME_SHC_MEDIATED_CASCADE_FGFR4 FGF18
#  5 REACTOME_SHC_MEDIATED_CASCADE_FGFR4 FGF19
#  6 REACTOME_SHC_MEDIATED_CASCADE_FGFR4 FGF2
#  7 REACTOME_SHC_MEDIATED_CASCADE_FGFR4 FGF20
#  8 REACTOME_SHC_MEDIATED_CASCADE_FGFR4 FGF23
#  9 REACTOME_SHC_MEDIATED_CASCADE_FGFR4 FGF4
# 10 REACTOME_SHC_MEDIATED_CASCADE_FGFR4 FGF6
# # i 11 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[1512]]
# # A tibble: 10 x 2
#    Pathway                                        Genes
#    <chr>                                          <chr>
#  1 REACTOME_SHC_RELATED_EVENTS_TRIGGERED_BY_IGF1R GRB2
#  2 REACTOME_SHC_RELATED_EVENTS_TRIGGERED_BY_IGF1R HRAS
#  3 REACTOME_SHC_RELATED_EVENTS_TRIGGERED_BY_IGF1R HRAS
#  4 REACTOME_SHC_RELATED_EVENTS_TRIGGERED_BY_IGF1R IGF1
#  5 REACTOME_SHC_RELATED_EVENTS_TRIGGERED_BY_IGF1R IGF1R
#  6 REACTOME_SHC_RELATED_EVENTS_TRIGGERED_BY_IGF1R IGF2
#  7 REACTOME_SHC_RELATED_EVENTS_TRIGGERED_BY_IGF1R KRAS
#  8 REACTOME_SHC_RELATED_EVENTS_TRIGGERED_BY_IGF1R NRAS
#  9 REACTOME_SHC_RELATED_EVENTS_TRIGGERED_BY_IGF1R SHC1
# 10 REACTOME_SHC_RELATED_EVENTS_TRIGGERED_BY_IGF1R SOS1
#
# [[1513]]
# # A tibble: 41 x 2
#    Pathway                         Genes
#    <chr>                           <chr>
#  1 REACTOME_SIALIC_ACID_METABOLISM CMAS
#  2 REACTOME_SIALIC_ACID_METABOLISM CTSA
#  3 REACTOME_SIALIC_ACID_METABOLISM GLB1
#  4 REACTOME_SIALIC_ACID_METABOLISM GNE
#  5 REACTOME_SIALIC_ACID_METABOLISM NANP
#  6 REACTOME_SIALIC_ACID_METABOLISM NANS
#  7 REACTOME_SIALIC_ACID_METABOLISM NEU1
#  8 REACTOME_SIALIC_ACID_METABOLISM NEU1
#  9 REACTOME_SIALIC_ACID_METABOLISM NEU1
# 10 REACTOME_SIALIC_ACID_METABOLISM NEU1
# # i 31 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[1514]]
# # A tibble: 15 x 2
#    Pathway                       Genes
#    <chr>                         <chr>
#  1 REACTOME_SIGNALING_BY_ACTIVIN ACVR1B
#  2 REACTOME_SIGNALING_BY_ACTIVIN ACVR1C
#  3 REACTOME_SIGNALING_BY_ACTIVIN ACVR2A
#  4 REACTOME_SIGNALING_BY_ACTIVIN ACVR2B
#  5 REACTOME_SIGNALING_BY_ACTIVIN DRAP1
#  6 REACTOME_SIGNALING_BY_ACTIVIN FOXH1
#  7 REACTOME_SIGNALING_BY_ACTIVIN FST
#  8 REACTOME_SIGNALING_BY_ACTIVIN FSTL3
#  9 REACTOME_SIGNALING_BY_ACTIVIN INHBA
# 10 REACTOME_SIGNALING_BY_ACTIVIN INHBB
# 11 REACTOME_SIGNALING_BY_ACTIVIN MAPK1
# 12 REACTOME_SIGNALING_BY_ACTIVIN MAPK3
# 13 REACTOME_SIGNALING_BY_ACTIVIN SMAD2
# 14 REACTOME_SIGNALING_BY_ACTIVIN SMAD3
# 15 REACTOME_SIGNALING_BY_ACTIVIN SMAD4
#
# [[1515]]
# # A tibble: 27 x 2
#    Pathway                   Genes
#    <chr>                     <chr>
#  1 REACTOME_SIGNALING_BY_ALK ALK
#  2 REACTOME_SIGNALING_BY_ALK CD274
#  3 REACTOME_SIGNALING_BY_ALK EP300
#  4 REACTOME_SIGNALING_BY_ALK FRS2
#  5 REACTOME_SIGNALING_BY_ALK HDAC1
#  6 REACTOME_SIGNALING_BY_ALK HDAC2
#  7 REACTOME_SIGNALING_BY_ALK HDAC3
#  8 REACTOME_SIGNALING_BY_ALK HIF1A
#  9 REACTOME_SIGNALING_BY_ALK IL2RG
# 10 REACTOME_SIGNALING_BY_ALK IRS1
# # i 17 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[1516]]
# # A tibble: 57 x 2
#    Pathway                             Genes
#    <chr>                               <chr>
#  1 REACTOME_SIGNALING_BY_ALK_IN_CANCER ALK
#  2 REACTOME_SIGNALING_BY_ALK_IN_CANCER ATIC
#  3 REACTOME_SIGNALING_BY_ALK_IN_CANCER BCL11A
#  4 REACTOME_SIGNALING_BY_ALK_IN_CANCER BCL2A1
#  5 REACTOME_SIGNALING_BY_ALK_IN_CANCER BIRC6
#  6 REACTOME_SIGNALING_BY_ALK_IN_CANCER CARS1
#  7 REACTOME_SIGNALING_BY_ALK_IN_CANCER CARS1
#  8 REACTOME_SIGNALING_BY_ALK_IN_CANCER CEBPB
#  9 REACTOME_SIGNALING_BY_ALK_IN_CANCER CLTC
# 10 REACTOME_SIGNALING_BY_ALK_IN_CANCER CUL1
# # i 47 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[1517]]
# # A tibble: 29 x 2
#    Pathway                   Genes
#    <chr>                     <chr>
#  1 REACTOME_SIGNALING_BY_BMP ACVR2A
#  2 REACTOME_SIGNALING_BY_BMP ACVR2B
#  3 REACTOME_SIGNALING_BY_BMP ACVRL1
#  4 REACTOME_SIGNALING_BY_BMP AMH
#  5 REACTOME_SIGNALING_BY_BMP AMHR2
#  6 REACTOME_SIGNALING_BY_BMP BMP10
#  7 REACTOME_SIGNALING_BY_BMP BMP2
#  8 REACTOME_SIGNALING_BY_BMP BMPR1A
#  9 REACTOME_SIGNALING_BY_BMP BMPR1B
# 10 REACTOME_SIGNALING_BY_BMP BMPR2
# # i 19 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[1518]]
# # A tibble: 67 x 2
#    Pathway                                     Genes
#    <chr>                                       <chr>
#  1 REACTOME_SIGNALING_BY_BRAF_AND_RAF1_FUSIONS ACTB
#  2 REACTOME_SIGNALING_BY_BRAF_AND_RAF1_FUSIONS ACTG1
#  3 REACTOME_SIGNALING_BY_BRAF_AND_RAF1_FUSIONS AGGF1
#  4 REACTOME_SIGNALING_BY_BRAF_AND_RAF1_FUSIONS AGK
#  5 REACTOME_SIGNALING_BY_BRAF_AND_RAF1_FUSIONS AGK
#  6 REACTOME_SIGNALING_BY_BRAF_AND_RAF1_FUSIONS AGTRAP
#  7 REACTOME_SIGNALING_BY_BRAF_AND_RAF1_FUSIONS AKAP9
#  8 REACTOME_SIGNALING_BY_BRAF_AND_RAF1_FUSIONS AP3B1
#  9 REACTOME_SIGNALING_BY_BRAF_AND_RAF1_FUSIONS APBB1IP
# 10 REACTOME_SIGNALING_BY_BRAF_AND_RAF1_FUSIONS ARAF
# # i 57 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[1519]]
# # A tibble: 30 x 2
#    Pathway                          Genes
#    <chr>                            <chr>
#  1 REACTOME_SIGNALING_BY_CSF3_G_CSF CSF3
#  2 REACTOME_SIGNALING_BY_CSF3_G_CSF CSF3R
#  3 REACTOME_SIGNALING_BY_CSF3_G_CSF CUL5
#  4 REACTOME_SIGNALING_BY_CSF3_G_CSF ELOB
#  5 REACTOME_SIGNALING_BY_CSF3_G_CSF ELOC
#  6 REACTOME_SIGNALING_BY_CSF3_G_CSF GAB2
#  7 REACTOME_SIGNALING_BY_CSF3_G_CSF GRB2
#  8 REACTOME_SIGNALING_BY_CSF3_G_CSF HCK
#  9 REACTOME_SIGNALING_BY_CSF3_G_CSF JAK1
# 10 REACTOME_SIGNALING_BY_CSF3_G_CSF JAK2
# # i 20 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[1520]]
# # A tibble: 15 x 2
#    Pathway                                           Genes
#    <chr>                                             <chr>
#  1 REACTOME_SIGNALING_BY_CTNNB1_PHOSPHO_SITE_MUTANTS AMER1
#  2 REACTOME_SIGNALING_BY_CTNNB1_PHOSPHO_SITE_MUTANTS APC
#  3 REACTOME_SIGNALING_BY_CTNNB1_PHOSPHO_SITE_MUTANTS AXIN1
#  4 REACTOME_SIGNALING_BY_CTNNB1_PHOSPHO_SITE_MUTANTS CSNK1A1
#  5 REACTOME_SIGNALING_BY_CTNNB1_PHOSPHO_SITE_MUTANTS CTNNB1
#  6 REACTOME_SIGNALING_BY_CTNNB1_PHOSPHO_SITE_MUTANTS GSK3B
#  7 REACTOME_SIGNALING_BY_CTNNB1_PHOSPHO_SITE_MUTANTS PPP2CA
#  8 REACTOME_SIGNALING_BY_CTNNB1_PHOSPHO_SITE_MUTANTS PPP2CB
#  9 REACTOME_SIGNALING_BY_CTNNB1_PHOSPHO_SITE_MUTANTS PPP2R1A
# 10 REACTOME_SIGNALING_BY_CTNNB1_PHOSPHO_SITE_MUTANTS PPP2R1B
# 11 REACTOME_SIGNALING_BY_CTNNB1_PHOSPHO_SITE_MUTANTS PPP2R5A
# 12 REACTOME_SIGNALING_BY_CTNNB1_PHOSPHO_SITE_MUTANTS PPP2R5B
# 13 REACTOME_SIGNALING_BY_CTNNB1_PHOSPHO_SITE_MUTANTS PPP2R5C
# 14 REACTOME_SIGNALING_BY_CTNNB1_PHOSPHO_SITE_MUTANTS PPP2R5D
# 15 REACTOME_SIGNALING_BY_CTNNB1_PHOSPHO_SITE_MUTANTS PPP2R5E
#
# [[1521]]
# # A tibble: 18 x 2
#    Pathway                                              Genes
#    <chr>                                                <chr>
#  1 REACTOME_SIGNALING_BY_CYTOSOLIC_FGFR1_FUSION_MUTANTS BCR
#  2 REACTOME_SIGNALING_BY_CYTOSOLIC_FGFR1_FUSION_MUTANTS CEP43
#  3 REACTOME_SIGNALING_BY_CYTOSOLIC_FGFR1_FUSION_MUTANTS CNTRL
#  4 REACTOME_SIGNALING_BY_CYTOSOLIC_FGFR1_FUSION_MUTANTS CPSF6
#  5 REACTOME_SIGNALING_BY_CYTOSOLIC_FGFR1_FUSION_MUTANTS CUX1
#  6 REACTOME_SIGNALING_BY_CYTOSOLIC_FGFR1_FUSION_MUTANTS FGFR1OP2
#  7 REACTOME_SIGNALING_BY_CYTOSOLIC_FGFR1_FUSION_MUTANTS GAB2
#  8 REACTOME_SIGNALING_BY_CYTOSOLIC_FGFR1_FUSION_MUTANTS GRB2
#  9 REACTOME_SIGNALING_BY_CYTOSOLIC_FGFR1_FUSION_MUTANTS LRRFIP1
# 10 REACTOME_SIGNALING_BY_CYTOSOLIC_FGFR1_FUSION_MUTANTS MYO18A
# 11 REACTOME_SIGNALING_BY_CYTOSOLIC_FGFR1_FUSION_MUTANTS PIK3CA
# 12 REACTOME_SIGNALING_BY_CYTOSOLIC_FGFR1_FUSION_MUTANTS PIK3R1
# 13 REACTOME_SIGNALING_BY_CYTOSOLIC_FGFR1_FUSION_MUTANTS STAT1
# 14 REACTOME_SIGNALING_BY_CYTOSOLIC_FGFR1_FUSION_MUTANTS STAT3
# 15 REACTOME_SIGNALING_BY_CYTOSOLIC_FGFR1_FUSION_MUTANTS STAT5A
# 16 REACTOME_SIGNALING_BY_CYTOSOLIC_FGFR1_FUSION_MUTANTS STAT5B
# 17 REACTOME_SIGNALING_BY_CYTOSOLIC_FGFR1_FUSION_MUTANTS TRIM24
# 18 REACTOME_SIGNALING_BY_CYTOSOLIC_FGFR1_FUSION_MUTANTS ZMYM2
#
# [[1522]]
# # A tibble: 52 x 2
#    Pathway                    Genes
#    <chr>                      <chr>
#  1 REACTOME_SIGNALING_BY_EGFR AAMP
#  2 REACTOME_SIGNALING_BY_EGFR ADAM10
#  3 REACTOME_SIGNALING_BY_EGFR ADAM12
#  4 REACTOME_SIGNALING_BY_EGFR ADAM17
#  5 REACTOME_SIGNALING_BY_EGFR AREG
#  6 REACTOME_SIGNALING_BY_EGFR ARHGEF7
#  7 REACTOME_SIGNALING_BY_EGFR BTC
#  8 REACTOME_SIGNALING_BY_EGFR CBL
#  9 REACTOME_SIGNALING_BY_EGFR CDC42
# 10 REACTOME_SIGNALING_BY_EGFR CSK
# # i 42 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[1523]]
# # A tibble: 26 x 2
#    Pathway                              Genes
#    <chr>                                <chr>
#  1 REACTOME_SIGNALING_BY_EGFR_IN_CANCER AREG
#  2 REACTOME_SIGNALING_BY_EGFR_IN_CANCER BTC
#  3 REACTOME_SIGNALING_BY_EGFR_IN_CANCER CBL
#  4 REACTOME_SIGNALING_BY_EGFR_IN_CANCER CDC37
#  5 REACTOME_SIGNALING_BY_EGFR_IN_CANCER EGF
#  6 REACTOME_SIGNALING_BY_EGFR_IN_CANCER EGFR
#  7 REACTOME_SIGNALING_BY_EGFR_IN_CANCER EPGN
#  8 REACTOME_SIGNALING_BY_EGFR_IN_CANCER EREG
#  9 REACTOME_SIGNALING_BY_EGFR_IN_CANCER GAB1
# 10 REACTOME_SIGNALING_BY_EGFR_IN_CANCER GRB2
# # i 16 more rows
# # i Use `print(n = ...)` to see more rows
#
# [[1524]]
# # A tibble: 52 x 2
#    Pathway                     Genes
#    <chr>                       <chr>
#  1 REACTOME_SIGNALING_BY_ERBB2 AKT1
#  2 REACTOME_SIGNALING_BY_ERBB2 AKT2
#  3 REACTOME_SIGNALING_BY_ERBB2 AKT3
#  4 REACTOME_SIGNALING_BY_ERBB2 AKT3
#  5 REACTOME_SIGNALING_BY_ERBB2 BTC
#  6 REACTOME_SIGNALING_BY_ERBB2 CDC37
#  7 REACTOME_SIGNALING_BY_ERBB2 CUL5
#  8 REACTOME_SIGNALING_BY_ERBB2 DIAPH1
#  9 REACTOME_SIGNALING_BY_ERBB2 EGF
# 10 REACTOME_SIGNALING_BY_ERBB2 EGFR
# # i 42 more rows
# # i Use `print(n = ...)` to see more rows
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# %%R
# cell_types <- unique(peppa$celltype_consensus.l2)
# peppa <- SplitObject(peppa, split.by = "study_disease")

# %%
# %%R
# parallel::detectCores()
# Out:
# [1] 40

# %%
# %%R
# scpa_out <- list()
# for (i in cell_types) {
#
#   HBV <- seurat_extract(peppa$HBV,
#                             meta1 = "celltype_consensus.l2", value_meta1 = i)
#
#   HBV_HIV <- seurat_extract(peppa$HBV_HIV,
#                           meta1 = "celltype_consensus.l2", value_meta1 = i)
#
#   print(paste("comparing", i))
#   scpa_out[[i]] <- compare_pathways(list(HBV, HBV_HIV), hkr_sets, parallel= TRUE, cores = 8)
#
# # For faster analysis with parallel processing, use 'parallel = TRUE' and 'cores = x' arguments
#
# }
# Out:
# [1] "comparing NK.Adaptive.CCL4.CCL3"
# [1] "comparing NK.Adaptive"
# [1] "comparing NK.Mature"
# [1] "comparing NK.Prolifering"

# %%
# %%R
# saveRDS(scpa_out, paste0(out.dir, "/scpa_out.rds"))

# %%
# %%R
#
# plotlist <- lapply(names(scpa_out), function(x){
#     tmp <- scpa_out[[x]] %>%
#       mutate(color = case_when(FC > 5 & adjPval < 0.01 ~ '#6dbf88',
#                                FC < 5 & FC > -5 & adjPval < 0.01 ~ '#84b0f0',
#                                FC < -5 & adjPval < 0.01 ~ 'mediumseagreen',
#                                FC < 5 & FC > -5 & adjPval > 0.01 ~ 'black'))
#
#     highlight <- tmp %>%
#       filter(grepl(pattern = "TCR|ZAP", ignore.case = T, x = Pathway))
#
#     plot<- ggplot(tmp, aes(-FC, qval)) +
#       geom_vline(xintercept = c(-5, 5), linetype = "dashed", col = 'black', lwd = 0.3) +
#       geom_point(cex = 2.6, shape = 21, fill = rest_act$color, stroke = 0.3) +
#       geom_point(data = highlight, shape = 21, cex = 2.8, fill = "orangered2", color = "black", stroke = 0.3) +
#       xlim(-20, 80) +
#       ylim(0, 11) +
#       xlab("Enrichment") +
#       ylab("Qval") +
#       theme(panel.background = element_blank(),
#             panel.border = element_rect(fill = NA),
#             aspect.ratio = 1)+
#     title(x)
#     return(plot)
# })

# %%
# %%R
# length(plotlist())

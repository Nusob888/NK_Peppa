# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager
import seaborn as sns
import anndata
import scanpy as sc
import re
import decoupler as dc
import sc_toolbox
import random
import seaborn.objects as so

# %%
adata = sc.read_h5ad("/well/immune-rep/users/vbw431/Projects/Fairfax/Mel_all/data/h5ad/update/fairfax_azimuth_combat_atlas_final.h5ad")

# %%
meta = fairfax.obs[cols_extract].copy()

# %%
set(Tcells["celltype.l2"])
# Out:
# {'CD4.Bcell.Doublets',
#  'CD4.IFN.resp',
#  'CD4.KRLB1hi.GATA3hi',
#  'CD4.Monocyte.Doublets',
#  'CD4.Naive',
#  'CD4.Naive.CD52lo',
#  'CD4.TCM',
#  'CD4.TCM.CD52lo',
#  'CD4.TCM.KLRB1',
#  'CD4.TEM',
#  'CD4.TEM.Resting',
#  'CD4.TEMRA',
#  'CD4.Treg',
#  'CD8.Naive',
#  'CD8.Proliferating',
#  'CD8.TCM',
#  'CD8.TCM.CCL5',
#  'CD8.TEM',
#  'CD8.TEMRA',
#  'CD8.TEMRA.CMC1',
#  'MAIT',
#  'dnT',
#  'gdT'}

# %%
Tcells = Tcells[Tcells["celltype.l1"].isin(["CD4.Tcells", "CD8.GD.DN.MAIT.Tcells"])].copy()

# %%
Tcells.shape
# Out:
# (295796, 37)

# %%
Rob_tcr.shape
# Out:
# (267367, 117)

# %%
Tcells['cell_barcodes'] = Tcells.index

# %%
Tcells = Tcells["Ref_lab"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /well/immune-rep/users/vbw431/conda/ivybridge/envs/scverse_new/lib/python3.8/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /well/immune-rep/users/vbw431/conda/ivybridge/envs/scverse_new/lib/python3.8/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /well/immune-rep/users/vbw431/conda/ivybridge/envs/scverse_new/lib/python3.8/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
Tcells.to_csv('/well/immune-rep/users/vbw431/Projects/Fairfax/Mel_all/data/TCR_for_Esther.csv', index=False)

# %%
Rob_tcr = pd.read_csv("/well/immune-rep/users/vbw431/Projects/Fairfax/Mel_all/data/TCR_annot_meta_forRob.csv")
# Out:
# /tmp/ipykernel_33761/987855458.py:1: DtypeWarning: Columns (14,16,47,51,52,53,54,55,56,58,59,60,61,62,64,65,67,68,69,71,72,74,75,76,78,81,82,83) have mixed types. Specify dtype option on import or set low_memory=False.
#   Rob_tcr = pd.read_csv("/well/immune-rep/users/vbw431/Projects/Fairfax/Mel_all/data/TCR_annot_meta_forRob.csv")

# %%
set(Tcells["celltype.l2"])
# Out:
# {'CD4.Bcell.Doublets',
#  'CD4.IFN.resp',
#  'CD4.KRLB1hi.GATA3hi',
#  'CD4.Monocyte.Doublets',
#  'CD4.Naive',
#  'CD4.Naive.CD52lo',
#  'CD4.TCM',
#  'CD4.TCM.CD52lo',
#  'CD4.TCM.KLRB1',
#  'CD4.TEM',
#  'CD4.TEM.Resting',
#  'CD4.TEMRA',
#  'CD4.Treg',
#  'CD8.Naive',
#  'CD8.Proliferating',
#  'CD8.TCM',
#  'CD8.TCM.CCL5',
#  'CD8.TEM',
#  'CD8.TEMRA',
#  'CD8.TEMRA.CMC1',
#  'MAIT',
#  'dnT',
#  'gdT'}

# %%
Rob_tcr.shape
# Out:
# (267367, 117)

# %%
Tcells[Tcells["vireo_geno_donorID"] == "Not applicable"]
# Out:
#                            Source cycle vireo_geno_donorID meta_batch  \
# L1_AAACCCAAGACATACA          PBMC   NaN     Not applicable    Azimuth
# L1_AAACCCACAACTGGTT          PBMC   NaN     Not applicable    Azimuth
# L1_AAACCCACAGCATACT          PBMC   NaN     Not applicable    Azimuth
# L1_AAACCCACATCAGTCA          PBMC   NaN     Not applicable    Azimuth
# L1_AAACCCATCCACACCT          PBMC   NaN     Not applicable    Azimuth
# ...                           ...   ...                ...        ...
# TTTCCTCTCAGAGGTG-1-gPlexK7   PBMC   NaN     Not applicable     COMBAT
# TTTGCGCCAAGGTTTC-1-gPlexK7   PBMC   NaN     Not applicable     COMBAT
# TTTGGTTAGCCGGTAA-1-gPlexK7   PBMC   NaN     Not applicable     COMBAT
# TTTGGTTCATGGTCAT-1-gPlexK7   PBMC   NaN     Not applicable     COMBAT
# TTTGGTTGTCTGCAAT-1-gPlexK7   PBMC   NaN     Not applicable     COMBAT
#
#                                       celltype.l1   celltype.l2 tumour_type  \
# ...

# %%
Tcells =
# Out:
# (446584, 37)

# %%
set(Tcells["Source"])
# Out:
# {'BCELL', 'BCELL_MONO', 'CD8', 'PBMC', 'Synovium', 'TCELL'}

# %%
pd.crosstab(adata.obs["vireo_geno_donorID"], adata.obs["Source"])
# Out:
# Source              BCELL  BCELL_MONO  CD8  PBMC  Synovium  TCELL
# vireo_geno_donorID
# 74_C1                   0           0    0  2355         0      0
# 74_C2                   0           0    0  2106         0      0
# 75_C1                   0           0    0   349         0      0
# 75_C2                   0           0    0  1064         0      0
# 161_C1                  0           0    0  2063         0      0
# ...                   ...         ...  ...   ...       ...    ...
# donor3              10360           0    0     0         0      0
# donor4               1817           0    0     0         0      0
# donor5                446           0    0     0         0      0
# donor6                873           0    0     0         0      0
# donor7               3918           0    0     0         0      0
#
# [111 rows x 6 columns]

# %%
synovium = adata[adata.obs["Source"]=="Synovium"].copy()

# %%
pd.crosstab(synovium.obs["vireo_geno_donorID"], synovium.obs["Source"])
# Out:
# Source              Synovium
# vireo_geno_donorID
# 194_SFL                 3519
# 194_SFR                 1814

# %%
set(adata.obs["vireo_geno_donorID"])
# Out:
# {'161_C1',
#  '161_C2',
#  '194_C1',
#  '194_C2',
#  '194_SFL',
#  '194_SFR',
#  '74_C1',
#  '74_C2',
#  '75_C1',
#  '75_C2',
#  '814',
#  '815',
#  'H_724',
#  'H_738',
#  'H_812',
#  'L_Leeds143',
#  'L_Leeds153',
#  'L_Leeds519',
#  'L_Leeds672',
#  'L_Leeds693',
#  'L_LeedsH1',
#  'L_LeedsH2',
#  'L_LeedsH3',
#  'L_LeedsH4',
#  'L_LeedsH5',
#  'L_LeedsP1',
#  'L_LeedsP10',
#  'L_LeedsP2',
#  'L_LeedsP3',
#  'L_LeedsP4',
#  'L_LeedsP5',
#  'L_LeedsP6',
#  'L_LeedsP7',
#  'L_LeedsP8',
#  'L_LeedsP9',
#  'M_103',
#  'M_104',
#  'M_107',
#  'M_113',
#  'M_124',
#  'M_125',
#  'M_132',
#  'M_133',
#  'M_136',
#  'M_139',
#  'M_146',
#  'M_153',
#  'M_155',
#  'M_156',
#  'M_160',
#  'M_162',
#  'M_164',
#  'M_172',
#  'M_174',
#  'M_175',
#  'M_183',
#  'M_192',
#  'M_193',
#  'M_194',
#  'M_203',
#  'M_205',
#  'M_209',
#  'M_210',
#  'M_213',
#  'M_214',
#  'M_219',
#  'M_224',
#  'M_225',
#  'M_232',
#  'M_242',
#  'M_27',
#  'M_32',
#  'M_36',
#  'M_37',
#  'M_40',
#  'M_42',
# ...

# %%
p194 = adata[adata.obs["vireo_geno_donorID"].str.contains("194")].copy()

# %%
p194.shape
# Out:
# (9817, 37889)

# %%
p194 = adata[adata.obs["vireo_geno_donorID"].str.contains("194")].copy()
p194 = p194[p194.obs["celltype.l1"]!="Doublets"].copy()
p194.obs["celltype.intermediate"] = p194.obs["celltype.l2"].copy()
p194.obs["celltype.intermediate"] = p194.obs["celltype.intermediate"].astype(str)p194.obs["celltype.intermediate"][p194.obs["celltype.intermediate"].str.contains("CD4.TCM")] = "CD4.TCM"
p194.obs["celltype.intermediate"][p194.obs["celltype.intermediate"].str.contains("CD8.TCM")] = "CD8.TCM"
p194.obs["celltype.intermediate"][p194.obs["celltype.intermediate"].str.contains("CD4.TEM")] = "CD4.Teff"
p194.obs["celltype.intermediate"][p194.obs["celltype.intermediate"].str.contains("CD4.TEMRA")] = "CD4.Teff"
p194.obs["celltype.intermediate"][p194.obs["celltype.intermediate"].str.contains("CD8.TEM")] = "CD8.Teff"
p194.obs["celltype.intermediate"][p194.obs["celltype.intermediate"].str.contains("CD8.TEMRA")] = "CD8.Teff"

p194.obs["celltype.intermediate"][p194.obs["celltype.intermediate"].str.contains("CD8.TEMRA")] = "CD8.Teff"
p194.obs["celltype.intermediate"][p194.obs["celltype.intermediate"].str.contains("CD8.TEMRA")] = "CD8.Teff"
p194.obs["celltype.intermediate"][p194.obs["celltype.intermediate"].str.contains("CD8.TEMRA")] = "CD8.Teff"
p194.obs["celltype.intermediate"][p194.obs["celltype.intermediate"].str.contains("CD8.TEMRA")] = "CD8.Teff"
# Out:
# AnnData object with n_obs × n_vars = 8249 × 37889
# ...

# %%
##recalculate embedding for local data
tmp = p194.copy()
# Out:
# WARNING: adata.X seems to be already log-transformed.

# %%
sc.pp.highly_variable_genes(tmp, n_top_genes= 2000, flavor= "seurat_v3")

# %%
sc.pl.highly_variable_genes(tmp)

# %%
tmp = tmp[:, tmp.var.highly_variable]

# %%
set(tmp.obs)
# Out:
# {'BCR1_IGH_c_gene',
#  'BCR1_IGH_cdr3',
#  'BCR1_IGH_d_gene',
#  'BCR1_IGH_j_gene',
#  'BCR1_IGH_umis',
#  'BCR1_IGH_v_gene',
#  'BCR1_IGKL_c_gene',
#  'BCR1_IGKL_cdr3',
#  'BCR1_IGKL_chain',
#  'BCR1_IGKL_d_gene',
#  'BCR1_IGKL_j_gene',
#  'BCR1_IGKL_umis',
#  'BCR1_IGKL_v_gene',
#  'BCR2_IGH_c_gene',
#  'BCR2_IGH_cdr3',
#  'BCR2_IGH_d_gene',
#  'BCR2_IGH_j_gene',
#  'BCR2_IGH_umis',
#  'BCR2_IGH_v_gene',
#  'BCR2_IGKL_c_gene',
#  'BCR2_IGKL_cdr3',
#  'BCR2_IGKL_chain',
#  'BCR2_IGKL_d_gene',
#  'BCR2_IGKL_j_gene',
#  'BCR2_IGKL_umis',
#  'BCR2_IGKL_v_gene',
#  'BCR_det',
#  'BCR_doub',
#  'Dataset',
#  'Harmonized_ID_x',
#  'Harmonized_ID_y',
#  'QC_label',
#  'QC_umi_feat',
#  'Ref_lab',
#  'Source',
#  'Subset_param',
#  'TCR_TRA1_c_gene',
#  'TCR_TRA1_cdr3',
#  'TCR_TRA1_d_gene',
#  'TCR_TRA1_j_gene',
#  'TCR_TRA1_umis',
#  'TCR_TRA1_v_gene',
#  'TCR_TRA2_c_gene',
#  'TCR_TRA2_cdr3',
#  'TCR_TRA2_d_gene',
#  'TCR_TRA2_j_gene',
#  'TCR_TRA2_umis',
#  'TCR_TRA2_v_gene',
# ...

# %%
sc.pp.scale(tmp, max_value=10)

# %%
sc.tl.pca(tmp, svd_solver='arpack')

# %%
sc.pp.neighbors(tmp, n_neighbors=10, n_pcs=40, metric = "cosine")
sc.tl.umap(tmp)

# %%
sc.pl.umap(tmp, color=["Source", "celltype.intermediate"], size=15)
# Out:
# /well/immune-rep/users/vbw431/conda/ivybridge/envs/scverse_new/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /well/immune-rep/users/vbw431/conda/ivybridge/envs/scverse_new/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
marker_genes_dict = {'B-cell': ['CD79A', 'MS4A1'],
                     'T-cell CD8+': ['CD3D','CD8A', 'CD8B'],
                     'NK': ['GNLY', 'NKG7'],
                     'Myeloid': ['CST3', 'LYZ'],
                     'Monocytes': ['FCGR3A'],
                     'Dendritic': ['FCER1A']}

# %%
tmp2 = tmp.copy()
tmp2 = tmp2[tmp2.obs["celltype.l1"]!="Doublets"].copy()
sc.tl.rank_genes_groups(tmp2, 'celltype.l2', method='wilcoxon')
# Out:
# /well/immune-rep/users/vbw431/conda/ivybridge/envs/scverse_new/lib/python3.8/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /well/immune-rep/users/vbw431/conda/ivybridge/envs/scverse_new/lib/python3.8/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /well/immune-rep/users/vbw431/conda/ivybridge/envs/scverse_new/lib/python3.8/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /well/immune-rep/users/vbw431/conda/ivybridge/envs/scverse_new/lib/python3.8/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# ...

# %%
sc.pl.rank_genes_groups_dotplot(tmp2, groupby='celltype.l2', n_genes=4)
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_celltype.l2). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
# /well/immune-rep/users/vbw431/conda/ivybridge/envs/scverse_new/lib/python3.8/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
p194.obs["celltype.l2"].value_counts()
# Out:
# cMono                    1984
# Mono.Doublets            1439
# CD4.TCM                   679
# CD8.TCM.CCL5              573
# CD4.TEM                   418
# B.unswMBC                 397
# NK                        356
# CD4.Naive                 305
# B.Naive                   287
# CD8.TEM                   282
# ncMono                    272
# cDC2                      270
# CD4.TCM.KLRB1             241
# MAIT                      201
# cDC1                      177
# pDC                       175
# CD8.Naive                 168
# NK.CD56bright             160
# CD8.Proliferating         157
# B.swMBC                   150
# CD4.TEM.Resting           123
# gdT                       119
# CD8.TCM                   105
# B.Doublets                 80
# CD4.Treg                   79
# CD8.TEMRA                  76
# B.DN.ITGAX                 75
# cMono.Plt                  54
# CD8.TEMRA.CMC1             44
# dnT                        43
# NK.Mitohi                  40
# ...

# %%
# Out:
# /tmp/ipykernel_33761/3964097505.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p194.obs["celltype.intermediate"][p194.obs["celltype.intermediate"].str.contains("CD4.TCM")] = "CD4.TCM"
# /tmp/ipykernel_33761/3964097505.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p194.obs["celltype.intermediate"][p194.obs["celltype.intermediate"].str.contains("CD8.TCM")] = "CD8.TCM"
# /tmp/ipykernel_33761/3964097505.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# Out:
# Pool3_Bcell_AAACCTGTCAATCTCT-1          B.Naive
# Pool3_Bcell_AAACGGGTCAGCACAT-1       B.Doublets
# Pool3_Bcell_AACCGCGCAGTCGTGC-1       B.DN.ITGAX
# Pool3_Bcell_AACTGGTGTCATCGGC-1            cMono
# Pool3_Bcell_AACTTTCAGATCGGGT-1       B.Doublets
#                                       ...
# P8.2_TTTGGTTTCGACCAGC-1                    cDC1
# P8.2_TTTGTCAAGAGACTTA-1           Mono.Doublets
# P8.2_TTTGTCAAGGCAGTCA-1                    ASDC
# P8.2_TTTGTCACACATCCAA-1                CD4.Teff
# P8.2_TTTGTCAGTTGACGTT-1           Mono.Doublets
# Name: celltype.intermediate, Length: 9817, dtype: object

# %%
# Out:
# /well/immune-rep/users/vbw431/conda/ivybridge/envs/scverse_new/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
